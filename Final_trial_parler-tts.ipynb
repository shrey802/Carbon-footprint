# %% [markdown]
# <a href="https://colab.research.google.com/github/shrey802/Carbon-footprint/blob/main/Final_trial_parler-tts.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Fine-tuning Parler-TTS
#
# ## Goal of this notebook
#
# In the following notebook, we'll fine-tune [Parler-TTS Mini v0.1](https://huggingface.co/parler-tts/parler_tts_mini_v0.1) on a 5h subset of the [Jenny TTS dataset](https://github.com/dioco-group/jenny-tts-dataset), a 30 hours high-quality mono-speaker TTS dataset, from an Irish female speaker named Jenny.
#
# In particular, we'll:
# - Annotate the Jenny dataset with natural language speech description using [Data-Speech](https://github.com/huggingface/dataspeech).
# - Fine-tune Parler-TTS with the created dataset.
#
# **You should be able to adapt this notebook to your own datasets quite easily.**

# %% [markdown]
# ## Prepare the Environment
#
# Throughout this tutorial, we'll use a GPU. The runtime is already configured to use the free 16GB T4 GPU provided through Google Colab Free Tier, so all you need to do is hit "Connect T4" in the top right-hand corner of the screen.
#
# ##### <a name="installation"> We'll install Parler-TTS and Data-Speech from source in order to train our model.

# %%
# !git clone https://github.com/huggingface/dataspeech.git
# !cd dataspeech
# !pip install --quiet -r ./dataspeech/requirements.txt
# Out:
# Cloning into 'dataspeech'...
# remote: Enumerating objects: 650, done.
# remote: Counting objects: 100% (221/221), done.
# remote: Compressing objects: 100% (90/90), done.
# remote: Total 650 (delta 138), reused 131 (delta 131), pack-reused 429 (from 1)
# Receiving objects: 100% (650/650), 158.78 KiB | 17.64 MiB/s, done.
# Resolving deltas: 100% (395/395), done.
#      \ 49.0 MB 15.0 MB/s 0:00:06
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 48.2 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.4/40.4 kB 3.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 125.2/125.2 kB 7.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 87.1/87.1 kB 6.7 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.6/59.6 kB 1.9 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#   Preparing metadata (setup.py) ... done
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.0/53.0 kB 3.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 117.0/117.0 kB 10.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#   Preparing metadata (setup.py) ... done
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 873.5/873.5 kB 51.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.8/61.8 kB 4.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 7.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.1/76.1 MB 9.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.0/46.0 kB 3.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 10.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 249.7/249.7 kB 19.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 143.5/143.5 kB 11.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.4/75.4 kB 6.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 423.9/423.9 kB 18.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 59.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 3.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 105.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 83.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 48.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 12.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 6.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 92.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 485.4/485.4 kB 30.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.0/40.0 kB 3.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.8/194.8 kB 17.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.8/86.8 kB 8.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 815.2/815.2 kB 41.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.5/79.5 kB 7.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.5/58.5 kB 5.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.1/48.1 kB 3.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 51.4/51.4 kB 3.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 125.9/125.9 kB 10.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 824.8/824.8 kB 48.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 101.7/101.7 kB 8.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.5/48.5 kB 3.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 931.6/931.6 kB 53.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 58.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 74.9/74.9 kB 7.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 383.6/383.6 kB 29.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 819.3/819.3 kB 42.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 231.8/231.8 kB 19.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 117.7/117.7 kB 10.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 739.1/739.1 kB 44.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.5/78.5 kB 6.2 MB/s eta 0:00:00
#   Building wheel for brouhaha (setup.py) ... done
#   Building wheel for demucs (setup.py) ... done
#   Building wheel for julius (setup.py) ... done
#   Building wheel for dora-search (pyproject.toml) ... done
#   Building wheel for antlr4-python3-runtime (setup.py) ... done
#   Building wheel for treetable (setup.py) ... done
#   Building wheel for unicodecsv (setup.py) ... done
#   Building wheel for docopt (setup.py) ... done
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# albumentations 2.0.5 requires pydantic>=2.9.2, but you have pydantic 2.8.2 which is incompatible.

# %%
# !git clone https://github.com/huggingface/parler-tts.git
# %cd parler-tts
# !pip install --quiet -e .[train]
# Out:
# Cloning into 'parler-tts'...
# remote: Enumerating objects: 1100, done.
# remote: Counting objects: 100% (457/457), done.
# remote: Compressing objects: 100% (177/177), done.
# remote: Total 1100 (delta 344), reused 280 (delta 280), pack-reused 643 (from 2)
# Receiving objects: 100% (1100/1100), 356.63 KiB | 5.17 MiB/s, done.
# Resolving deltas: 100% (702/702), done.
# /content/parler-tts
#   Installing build dependencies ... done
#   Checking if build backend supports build_editable ... done
#   Getting requirements to build editable ... done
#   Preparing editable metadata (pyproject.toml) ... done
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.1/44.1 kB 2.7 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 64.2/64.2 kB 4.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 87.2/87.2 kB 7.4 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.0/10.0 MB 49.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.0/84.0 kB 7.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 84.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.0/3.0 MB 91.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.5/48.5 kB 3.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 63.6 MB/s eta 0:00:00
#   Building editable for parler_tts (pyproject.toml) ... done
#   Building wheel for descript-audiotools (setup.py) ... done
#   Building wheel for argbind (setup.py) ... done
#   Building wheel for randomname (setup.py) ... done
#   Building wheel for fire (setup.py) ... done

# %% [markdown]
# On Colab, we need to run an additional set-up, that you can skip if you're on your local machine.

# %%
# !pip install --upgrade protobuf wandb==0.16.6
# Out:
# Requirement already satisfied: protobuf in /usr/local/lib/python3.11/dist-packages (4.25.6)
# Collecting protobuf
#   Downloading protobuf-6.30.0-cp39-abi3-manylinux2014_x86_64.whl.metadata (593 bytes)
# Collecting wandb==0.16.6
#   Downloading wandb-0.16.6-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: Click!=8.0.0,>=7.1 in /usr/local/lib/python3.11/dist-packages (from wandb==0.16.6) (8.1.8)
# Requirement already satisfied: GitPython!=3.1.29,>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from wandb==0.16.6) (3.1.44)
# Requirement already satisfied: requests<3,>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from wandb==0.16.6) (2.32.3)
# Requirement already satisfied: psutil>=5.0.0 in /usr/local/lib/python3.11/dist-packages (from wandb==0.16.6) (5.9.5)
# Requirement already satisfied: sentry-sdk>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from wandb==0.16.6) (2.22.0)
# Requirement already satisfied: docker-pycreds>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from wandb==0.16.6) (0.4.0)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.11/dist-packages (from wandb==0.16.6) (6.0.2)
# Requirement already satisfied: setproctitle in /usr/local/lib/python3.11/dist-packages (from wandb==0.16.6) (1.3.5)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.11/dist-packages (from wandb==0.16.6) (75.1.0)
# Collecting appdirs>=1.4.3 (from wandb==0.16.6)
#   Downloading appdirs-1.4.4-py2.py3-none-any.whl.metadata (9.0 kB)
# Requirement already satisfied: six>=1.4.0 in /usr/local/lib/python3.11/dist-packages (from docker-pycreds>=0.4.0->wandb==0.16.6) (1.17.0)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /usr/local/lib/python3.11/dist-packages (from GitPython!=3.1.29,>=1.0.0->wandb==0.16.6) (4.0.12)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.0.0->wandb==0.16.6) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.0.0->wandb==0.16.6) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.0.0->wandb==0.16.6) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.0.0->wandb==0.16.6) (2025.1.31)
# Requirement already satisfied: smmap<6,>=3.0.1 in /usr/local/lib/python3.11/dist-packages (from gitdb<5,>=4.0.1->GitPython!=3.1.29,>=1.0.0->wandb==0.16.6) (5.0.2)
# Downloading wandb-0.16.6-py3-none-any.whl (2.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 69.7 MB/s eta 0:00:00
# Downloading appdirs-1.4.4-py2.py3-none-any.whl (9.6 kB)
# Installing collected packages: appdirs, wandb
#   Attempting uninstall: wandb
#     Found existing installation: wandb 0.19.8
#     Uninstalling wandb-0.19.8:
#       Successfully uninstalled wandb-0.19.8
# Successfully installed appdirs-1.4.4 wandb-0.16.6

# %% [markdown]
# You should link you Hugging Face account so that you can push model repositories on the Hub. This will allow you to save your trained models on the Hub so that you can share them with the community.
#
# Run the command below and then enter an authentication token from https://huggingface.co/settings/tokens. Create a new token if you do not have one already. You should make sure that this token has "write" privileges.

# %%
# !git config --global credential.helper store
# !huggingface-cli login
# Out:
#     _|    _|  _|    _|    _|_|_|    _|_|_|  _|_|_|  _|      _|    _|_|_|      _|_|_|_|    _|_|      _|_|_|  _|_|_|_|
#     _|    _|  _|    _|  _|        _|          _|    _|_|    _|  _|            _|        _|    _|  _|        _|
#     _|_|_|_|  _|    _|  _|  _|_|  _|  _|_|    _|    _|  _|  _|  _|  _|_|      _|_|_|    _|_|_|_|  _|        _|_|_|
#     _|    _|  _|    _|  _|    _|  _|    _|    _|    _|    _|_|  _|    _|      _|        _|    _|  _|        _|
#     _|    _|    _|_|      _|_|_|    _|_|_|  _|_|_|  _|      _|    _|_|_|      _|        _|    _|    _|_|_|  _|_|_|_|
#
#     To log in, `huggingface_hub` requires a token generated from https://huggingface.co/settings/tokens .
# Enter your token (input will not be visible):
# Add token as git credential? (Y/n) Y
# Token is valid (permission: fineGrained).
# The token `HF_Token` has been saved to /root/.cache/huggingface/stored_tokens
# Your token has been saved in your configured git credential helpers (store).
# Your token has been saved to /root/.cache/huggingface/token
# Login successful.
# The current active token is: `HF_Token`

# %% [markdown]
# ## 1. Creating our fine-tuning dataset
#
#
# The aim here is to create an annotated version of Jenny TTS, in order to fine-tune the [Parler-TTS v0.1 checkpoint](https://huggingface.co/parler-tts/parler_tts_mini_v0.1) on this dataset.
#
# Thanks to a [script similar to what's described in the Data-Speech FAQ](https://github.com/huggingface/dataspeech?tab=readme-ov-file#how-do-i-use-datasets-that-i-have-with-this-repository), we've uploaded the dataset to the HuggingFace hub, under the name [reach-vb/jenny_tts_dataset](https://huggingface.co/datasets/reach-vb/jenny_tts_dataset).
#
# The purpose of this notebook is demonstration so we've pushed a 6h subset of the dataset that we'll work with: [ylacombe/jenny-tts-6h](https://huggingface.co/datasets/ylacombe/jenny-tts-6h).
#
# Feel free to follow the link above to listen to some samples of the Jenny TTS dataset thanks to the hub viewer.
#
# > Refer to the [Data-Speech README](https://github.com/huggingface/dataspeech?tab=readme-ov-file#data-speech) for more detailed explanations of what's going on under-the-hood.
#
# We'll:
# 1. Annotate the Jenny dataset with continuous variables that measures the speech characteristics
# 2. Map those annotations to text bins that characterize the speech characteristics.
# 3. Create natural language descriptions from those text bins

# %%
# %cd ../dataspeech
# Out:
# /content/dataspeech

# %% [markdown]
# But first, let's look at a few samples from the Jenny dataset!

# %%
from datasets import load_dataset
dataset = load_dataset("ylacombe/jenny-tts-6h")
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# README.md:   0%|          | 0.00/420 [00:00<?, ?B/s]
# train-00000-of-00003.parquet:   0%|          | 0.00/326M [00:00<?, ?B/s]
# train-00001-of-00003.parquet:   0%|          | 0.00/371M [00:00<?, ?B/s]
# train-00002-of-00003.parquet:   0%|          | 0.00/319M [00:00<?, ?B/s]
# Generating train split:   0%|          | 0/4000 [00:00<?, ? examples/s]

# %%
from IPython.display import Audio
print(dataset["train"][0]["transcription"])
Audio(dataset["train"][0]["audio"]["array"], rate=dataset["train"][0]["audio"]["sampling_rate"])
# Out:
# It was a bright cold day in April, and the clocks were striking thirteen.
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
from IPython.display import Audio
print(dataset["train"][1]["transcription"])
Audio(dataset["train"][1]["audio"]["array"], rate=dataset["train"][1]["audio"]["sampling_rate"])
# Out:
# 'I wonder if I shall ever be happy enough to have real lace on my clothes and bows on my caps?'
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
del dataset

# %% [markdown]
# ### Annotating the Jenny dataset
#
# We'll use [`main.py`](https://github.com/huggingface/dataspeech/blob/main/main.py) to get the following continuous variables:
# - Speaking rate `(nb_phonemes / utterance_length)`
# - Signal-to-noise ratio (SNR)
# - Reverberation
# - Speech monotony

# %%
# !python main.py "ylacombe/jenny-tts-6h" \
  --configuration "default" \
  --text_column_name "transcription" \
  --audio_column_name "audio" \
  --cpu_num_workers 2 \
  --num_workers_per_gpu_for_pitch 2 \
  --rename_column \
  --repo_id "jenny-tts-tags-6h"
# Out:
# 2025-03-12 05:23:06.745599: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1741756987.061354    3885 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1741756987.146921    3885 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-03-12 05:23:07.841659: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# The cache for model files in Transformers v4.22.0 has been updated. Migrating your old cache. This is a one-time only operation. You can interrupt this and resume the migration later on by calling `transformers.utils.move_cache()`.
# 0it [00:00, ?it/s]
# INFO - Applied quirks (see `speechbrain.utils.quirks`): [disable_jit_profiling, allow_tf32]
# INFO - Excluded quirks specified by the `SB_DISABLE_QUIRKS` environment (comma-separated list): []
# /usr/local/lib/python3.11/dist-packages/pyannote/audio/pipelines/speaker_verification.py:43: UserWarning: Module 'speechbrain.pretrained' was deprecated, redirecting to 'speechbrain.inference'. Please update your script. This is a change from SpeechBrain 1.0. See: https://github.com/speechbrain/speechbrain/releases/tag/v1.0.0
#   from speechbrain.pretrained import (
# Compute pitch
# Map (num_proc=2):   0% 0/4000 [00:00<?, ? examples/s]2025-03-12 05:23:40.049474: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1741757020.120051    4037 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1741757020.130771    4037 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-03-12 05:23:40.654219: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1741757020.728596    4038 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1741757020.754659    4038 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-03-12 05:23:40.923524: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1741757020.965560    4042 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1741757020.980205    4042 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# INFO - Applied quirks (see `speechbrain.utils.quirks`): [allow_tf32, disable_jit_profiling]
# INFO - Excluded quirks specified by the `SB_DISABLE_QUIRKS` environment (comma-separated list): []
# /usr/local/lib/python3.11/dist-packages/pyannote/audio/pipelines/speaker_verification.py:43: UserWarning: Module 'speechbrain.pretrained' was deprecated, redirecting to 'speechbrain.inference'. Please update your script. This is a change from SpeechBrain 1.0. See: https://github.com/speechbrain/speechbrain/releases/tag/v1.0.0
#   from speechbrain.pretrained import (
# INFO - Applied quirks (see `speechbrain.utils.quirks`): [disable_jit_profiling, allow_tf32]
# INFO - Excluded quirks specified by the `SB_DISABLE_QUIRKS` environment (comma-separated list): []
# /usr/local/lib/python3.11/dist-packages/pyannote/audio/pipelines/speaker_verification.py:43: UserWarning: Module 'speechbrain.pretrained' was deprecated, redirecting to 'speechbrain.inference'. Please update your script. This is a change from SpeechBrain 1.0. See: https://github.com/speechbrain/speechbrain/releases/tag/v1.0.0
#   from speechbrain.pretrained import (
# INFO - Applied quirks (see `speechbrain.utils.quirks`): [allow_tf32, disable_jit_profiling]
# INFO - Excluded quirks specified by the `SB_DISABLE_QUIRKS` environment (comma-separated list): []
# /usr/local/lib/python3.11/dist-packages/pyannote/audio/pipelines/speaker_verification.py:43: UserWarning: Module 'speechbrain.pretrained' was deprecated, redirecting to 'speechbrain.inference'. Please update your script. This is a change from SpeechBrain 1.0. See: https://github.com/speechbrain/speechbrain/releases/tag/v1.0.0
#   from speechbrain.pretrained import (
# fcnf0%2B%2B.pt: 100% 107M/107M [00:01<00:00, 78.6MB/s]
# /usr/local/lib/python3.11/dist-packages/penn/core.py:421: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   checkpoint = torch.load(checkpoint, map_location='cpu')
# /usr/local/lib/python3.11/dist-packages/penn/core.py:421: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   checkpoint = torch.load(checkpoint, map_location='cpu')
# Map (num_proc=2): 100% 4000/4000 [04:14<00:00, 15.71 examples/s]
# Compute snr and reverb
# Map:   0% 0/4000 [00:00<?, ? examples/s]
# best.ckpt:   0% 0.00/47.2M [00:00<?, ?B/s]
# best.ckpt:  44% 21.0M/47.2M [00:00<00:00, 132MB/s]
# best.ckpt: 100% 47.2M/47.2M [00:00<00:00, 165MB/s]
# INFO - Lightning automatically upgraded your loaded checkpoint from v1.6.5 to v2.5.0.post0. To apply the upgrade to your files permanently, run `python -m pytorch_lightning.utilities.upgrade_checkpoint ../../root/.cache/huggingface/hub/models--ylacombe--brouhaha-best/snapshots/99bf97b13fd4dda2434a6f7c50855933076f2937/best.ckpt`
# Model was trained with pyannote.audio 0.0.1, yours is 3.2.0. Bad things might happen unless you revert pyannote.audio to 0.x.
# Model was trained with torch 1.12.1+cu102, yours is 2.5.1+cu124. Bad things might happen unless you revert torch to 1.x.
# Using default parameters optimized on Brouhaha
# /usr/local/lib/python3.11/dist-packages/pyannote/audio/core/pipeline.py:317: UserWarning: The pipeline has been automatically instantiated with {'onset': 0.78, 'offset': 0.78, 'min_duration_on': 0, 'min_duration_off': 0}.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/pyannote/audio/utils/reproducibility.py:74: ReproducibilityWarning: TensorFloat-32 (TF32) has been disabled as it might lead to reproducibility issues and lower accuracy.
# It can be re-enabled by calling
#    >>> import torch
#    >>> torch.backends.cuda.matmul.allow_tf32 = True
#    >>> torch.backends.cudnn.allow_tf32 = True
# See https://github.com/pyannote/pyannote-audio/issues/1370 for more details.
#
#   warnings.warn(
# Map:   0% 2/4000 [00:02<1:26:16,  1.29s/ examples]Using default parameters optimized on Brouhaha
# Map:   0% 4/4000 [00:02<38:09,  1.75 examples/s]  Using default parameters optimized on Brouhaha
# Map:   0% 6/4000 [00:02<22:57,  2.90 examples/s]Using default parameters optimized on Brouhaha
# Map:   0% 8/4000 [00:03<16:06,  4.13 examples/s]Using default parameters optimized on Brouhaha
# Map:   0% 10/4000 [00:03<12:01,  5.53 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:   0% 14/4000 [00:03<08:24,  7.90 examples/s]Using default parameters optimized on Brouhaha
# Map:   0% 16/4000 [00:03<07:23,  8.98 examples/s]Using default parameters optimized on Brouhaha
# Map:   0% 18/4000 [00:03<06:29, 10.23 examples/s]Using default parameters optimized on Brouhaha
# Map:   0% 20/4000 [00:03<05:49, 11.38 examples/s]Using default parameters optimized on Brouhaha
# Map:   1% 22/4000 [00:03<05:22, 12.32 examples/s]Using default parameters optimized on Brouhaha
# Map:   1% 24/4000 [00:04<04:53, 13.55 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:   1% 28/4000 [00:04<04:10, 15.87 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:   1% 32/4000 [00:04<04:32, 14.55 examples/s]Using default parameters optimized on Brouhaha
# Map:   1% 34/4000 [00:04<04:24, 14.97 examples/s]Using default parameters optimized on Brouhaha
# Map:   1% 36/4000 [00:04<04:11, 15.73 examples/s]Using default parameters optimized on Brouhaha
# Map:   1% 38/4000 [00:05<04:39, 14.19 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:   1% 42/4000 [00:05<03:57, 16.63 examples/s]Using default parameters optimized on Brouhaha
# Map:   1% 44/4000 [00:05<04:00, 16.45 examples/s]Using default parameters optimized on Brouhaha
# Map:   1% 46/4000 [00:05<04:05, 16.10 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:   1% 50/4000 [00:05<03:43, 17.64 examples/s]Using default parameters optimized on Brouhaha
# Map:   1% 52/4000 [00:05<03:39, 17.98 examples/s]Using default parameters optimized on Brouhaha
# Map:   1% 54/4000 [00:05<04:19, 15.23 examples/s]Using default parameters optimized on Brouhaha
# Map:   1% 56/4000 [00:06<04:42, 13.95 examples/s]Using default parameters optimized on Brouhaha
# Map:   1% 58/4000 [00:06<05:21, 12.26 examples/s]Using default parameters optimized on Brouhaha
# Map:   2% 60/4000 [00:06<05:22, 12.22 examples/s]Using default parameters optimized on Brouhaha
# Map:   2% 62/4000 [00:06<05:10, 12.68 examples/s]Using default parameters optimized on Brouhaha
# Map:   2% 64/4000 [00:06<04:57, 13.22 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:   2% 68/4000 [00:06<03:55, 16.70 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:   2% 72/4000 [00:07<03:15, 20.08 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:   2% 76/4000 [00:07<02:49, 23.21 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:   2% 80/4000 [00:07<02:46, 23.53 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:   2% 84/4000 [00:07<02:42, 24.17 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:   2% 88/4000 [00:07<02:49, 23.10 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:   2% 92/4000 [00:07<02:38, 24.62 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:   2% 96/4000 [00:08<02:35, 25.11 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:   2% 100/4000 [00:08<02:38, 24.68 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:   3% 104/4000 [00:08<02:47, 23.30 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:   3% 108/4000 [00:08<02:55, 22.14 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:   3% 112/4000 [00:08<03:06, 20.82 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:   3% 116/4000 [00:09<03:34, 18.12 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:   3% 120/4000 [00:09<03:17, 19.69 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:   3% 124/4000 [00:09<03:15, 19.84 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:   3% 128/4000 [00:09<03:20, 19.30 examples/s]Using default parameters optimized on Brouhaha
# Map:   3% 130/4000 [00:09<03:35, 17.96 examples/s]Using default parameters optimized on Brouhaha
# Map:   3% 132/4000 [00:09<03:44, 17.21 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:   3% 136/4000 [00:10<03:22, 19.04 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:   4% 140/4000 [00:10<03:12, 20.01 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:   4% 144/4000 [00:10<03:00, 21.40 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:   4% 148/4000 [00:10<02:41, 23.85 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:   4% 152/4000 [00:10<02:48, 22.78 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:   4% 156/4000 [00:11<03:08, 20.39 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:   4% 160/4000 [00:11<02:55, 21.89 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:   4% 164/4000 [00:11<02:45, 23.18 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:   4% 168/4000 [00:11<02:40, 23.84 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:   4% 172/4000 [00:11<02:44, 23.34 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:   4% 176/4000 [00:11<02:28, 25.72 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:   4% 180/4000 [00:11<02:21, 27.01 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:   5% 184/4000 [00:12<02:15, 28.25 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:   5% 188/4000 [00:12<02:08, 29.59 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:   5% 192/4000 [00:12<02:20, 27.17 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:   5% 196/4000 [00:12<02:25, 26.09 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:   5% 200/4000 [00:12<02:34, 24.61 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:   5% 204/4000 [00:12<02:39, 23.85 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:   5% 208/4000 [00:13<02:51, 22.12 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:   5% 212/4000 [00:13<03:04, 20.50 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:   5% 216/4000 [00:13<02:54, 21.74 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:   6% 220/4000 [00:13<02:42, 23.20 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:   6% 224/4000 [00:13<02:37, 23.92 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:   6% 228/4000 [00:13<02:44, 22.95 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:   6% 232/4000 [00:14<02:53, 21.75 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:   6% 236/4000 [00:14<02:38, 23.82 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:   6% 240/4000 [00:14<02:43, 23.02 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:   6% 244/4000 [00:14<02:28, 25.28 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:   6% 248/4000 [00:14<02:39, 23.58 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:   6% 252/4000 [00:15<02:47, 22.39 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:   6% 256/4000 [00:15<02:58, 21.02 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:   6% 260/4000 [00:15<02:55, 21.35 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:   7% 264/4000 [00:15<03:08, 19.85 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:   7% 268/4000 [00:15<02:55, 21.32 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:   7% 272/4000 [00:16<03:19, 18.65 examples/s]Using default parameters optimized on Brouhaha
# Map:   7% 274/4000 [00:16<03:24, 18.21 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:   7% 278/4000 [00:16<03:14, 19.15 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:   7% 282/4000 [00:16<03:07, 19.78 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:   7% 286/4000 [00:16<03:29, 17.72 examples/s]Using default parameters optimized on Brouhaha
# Map:   7% 288/4000 [00:17<04:01, 15.35 examples/s]Using default parameters optimized on Brouhaha
# Map:   7% 290/4000 [00:17<04:18, 14.38 examples/s]Using default parameters optimized on Brouhaha
# Map:   7% 292/4000 [00:17<04:31, 13.65 examples/s]Using default parameters optimized on Brouhaha
# Map:   7% 294/4000 [00:17<04:57, 12.44 examples/s]Using default parameters optimized on Brouhaha
# Map:   7% 296/4000 [00:17<04:53, 12.64 examples/s]Using default parameters optimized on Brouhaha
# Map:   7% 298/4000 [00:17<04:55, 12.52 examples/s]Using default parameters optimized on Brouhaha
# Map:   8% 300/4000 [00:18<04:46, 12.90 examples/s]Using default parameters optimized on Brouhaha
# Map:   8% 302/4000 [00:18<04:34, 13.45 examples/s]Using default parameters optimized on Brouhaha
# Map:   8% 304/4000 [00:18<05:10, 11.91 examples/s]Using default parameters optimized on Brouhaha
# Map:   8% 306/4000 [00:18<05:27, 11.29 examples/s]Using default parameters optimized on Brouhaha
# Map:   8% 308/4000 [00:18<05:14, 11.74 examples/s]Using default parameters optimized on Brouhaha
# Map:   8% 310/4000 [00:18<05:25, 11.34 examples/s]Using default parameters optimized on Brouhaha
# Map:   8% 312/4000 [00:19<05:41, 10.81 examples/s]Using default parameters optimized on Brouhaha
# Map:   8% 314/4000 [00:19<05:25, 11.32 examples/s]Using default parameters optimized on Brouhaha
# Map:   8% 316/4000 [00:19<05:02, 12.18 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:   8% 320/4000 [00:19<03:54, 15.68 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:   8% 324/4000 [00:19<03:18, 18.48 examples/s]Using default parameters optimized on Brouhaha
# Map:   8% 326/4000 [00:19<03:27, 17.67 examples/s]Using default parameters optimized on Brouhaha
# Map:   8% 328/4000 [00:20<03:41, 16.56 examples/s]Using default parameters optimized on Brouhaha
# Map:   8% 330/4000 [00:20<03:58, 15.36 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:   8% 334/4000 [00:20<03:34, 17.11 examples/s]Using default parameters optimized on Brouhaha
# Map:   8% 336/4000 [00:20<03:27, 17.64 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:   8% 340/4000 [00:20<03:03, 19.93 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:   9% 344/4000 [00:20<02:54, 20.90 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:   9% 348/4000 [00:21<02:59, 20.34 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:   9% 352/4000 [00:21<02:52, 21.18 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:   9% 356/4000 [00:21<03:11, 19.08 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:   9% 360/4000 [00:21<03:17, 18.38 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:   9% 364/4000 [00:21<03:02, 19.92 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:   9% 368/4000 [00:22<02:59, 20.25 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:   9% 372/4000 [00:22<03:11, 18.99 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:   9% 376/4000 [00:22<03:12, 18.87 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:  10% 380/4000 [00:22<03:01, 19.97 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:  10% 384/4000 [00:22<02:41, 22.42 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:  10% 388/4000 [00:23<02:43, 22.13 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:  10% 392/4000 [00:23<02:37, 22.98 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:  10% 396/4000 [00:23<02:43, 22.00 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:  10% 400/4000 [00:23<02:54, 20.59 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:  10% 404/4000 [00:23<02:51, 20.98 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:  10% 408/4000 [00:23<02:33, 23.45 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:  10% 412/4000 [00:24<02:38, 22.65 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:  10% 416/4000 [00:24<02:56, 20.36 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:  10% 420/4000 [00:24<02:46, 21.54 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:  11% 424/4000 [00:24<02:42, 21.97 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:  11% 428/4000 [00:24<02:47, 21.39 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:  11% 432/4000 [00:25<03:10, 18.69 examples/s]Using default parameters optimized on Brouhaha
# Map:  11% 434/4000 [00:25<03:17, 18.08 examples/s]Using default parameters optimized on Brouhaha
# Map:  11% 436/4000 [00:25<03:31, 16.83 examples/s]Using default parameters optimized on Brouhaha
# Map:  11% 438/4000 [00:25<03:52, 15.30 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:  11% 442/4000 [00:25<03:17, 17.99 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:  11% 446/4000 [00:25<03:06, 19.04 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:  11% 450/4000 [00:26<02:51, 20.71 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:  11% 454/4000 [00:26<02:32, 23.20 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:  11% 458/4000 [00:26<02:34, 22.96 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:  12% 462/4000 [00:26<02:30, 23.47 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:  12% 466/4000 [00:26<02:57, 19.92 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:  12% 470/4000 [00:26<02:37, 22.42 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:  12% 474/4000 [00:27<03:08, 18.71 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:  12% 478/4000 [00:27<02:51, 20.58 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:  12% 482/4000 [00:27<02:45, 21.23 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:  12% 486/4000 [00:27<02:54, 20.09 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:  12% 490/4000 [00:28<02:55, 20.05 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:  12% 494/4000 [00:28<03:16, 17.87 examples/s]Using default parameters optimized on Brouhaha
# Map:  12% 496/4000 [00:28<03:25, 17.02 examples/s]Using default parameters optimized on Brouhaha
# Map:  12% 498/4000 [00:28<03:36, 16.14 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:  13% 502/4000 [00:28<03:21, 17.34 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:  13% 506/4000 [00:28<03:08, 18.52 examples/s]Using default parameters optimized on Brouhaha
# Map:  13% 508/4000 [00:29<03:08, 18.57 examples/s]Using default parameters optimized on Brouhaha
# Map:  13% 510/4000 [00:29<03:05, 18.79 examples/s]Using default parameters optimized on Brouhaha
# Map:  13% 512/4000 [00:29<03:18, 17.54 examples/s]Using default parameters optimized on Brouhaha
# Map:  13% 514/4000 [00:29<03:44, 15.54 examples/s]Using default parameters optimized on Brouhaha
# Map:  13% 516/4000 [00:29<03:58, 14.63 examples/s]Using default parameters optimized on Brouhaha
# Map:  13% 518/4000 [00:29<04:36, 12.58 examples/s]Using default parameters optimized on Brouhaha
# Map:  13% 520/4000 [00:30<04:49, 12.03 examples/s]Using default parameters optimized on Brouhaha
# Map:  13% 522/4000 [00:30<04:32, 12.75 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:  13% 526/4000 [00:30<04:18, 13.43 examples/s]Using default parameters optimized on Brouhaha
# Map:  13% 528/4000 [00:30<04:03, 14.26 examples/s]Using default parameters optimized on Brouhaha
# Map:  13% 530/4000 [00:30<03:57, 14.62 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:  13% 534/4000 [00:30<03:23, 17.02 examples/s]Using default parameters optimized on Brouhaha
# Map:  13% 536/4000 [00:30<03:18, 17.49 examples/s]Using default parameters optimized on Brouhaha
# Map:  13% 538/4000 [00:31<03:52, 14.91 examples/s]Using default parameters optimized on Brouhaha
# Map:  14% 540/4000 [00:31<04:11, 13.73 examples/s]Using default parameters optimized on Brouhaha
# Map:  14% 542/4000 [00:31<03:53, 14.78 examples/s]Using default parameters optimized on Brouhaha
# Map:  14% 544/4000 [00:31<03:36, 15.94 examples/s]Using default parameters optimized on Brouhaha
# Map:  14% 546/4000 [00:31<04:03, 14.19 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:  14% 550/4000 [00:31<03:37, 15.88 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:  14% 554/4000 [00:32<02:56, 19.53 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:  14% 558/4000 [00:32<03:05, 18.58 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:  14% 562/4000 [00:32<02:45, 20.74 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:  14% 566/4000 [00:32<02:47, 20.48 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:  14% 570/4000 [00:32<03:10, 18.01 examples/s]Using default parameters optimized on Brouhaha
# Map:  14% 572/4000 [00:33<03:16, 17.48 examples/s]Using default parameters optimized on Brouhaha
# Map:  14% 574/4000 [00:33<03:17, 17.33 examples/s]Using default parameters optimized on Brouhaha
# Map:  14% 576/4000 [00:33<03:19, 17.15 examples/s]Using default parameters optimized on Brouhaha
# Map:  14% 578/4000 [00:33<03:16, 17.39 examples/s]Using default parameters optimized on Brouhaha
# Map:  14% 580/4000 [00:33<03:23, 16.78 examples/s]Using default parameters optimized on Brouhaha
# Map:  15% 582/4000 [00:33<03:15, 17.45 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:  15% 586/4000 [00:33<02:42, 21.01 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:  15% 590/4000 [00:34<02:43, 20.84 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:  15% 594/4000 [00:34<03:07, 18.15 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:  15% 598/4000 [00:34<03:03, 18.52 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:  15% 602/4000 [00:34<02:49, 20.05 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:  15% 606/4000 [00:34<02:44, 20.57 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:  15% 610/4000 [00:34<02:34, 22.00 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:  15% 614/4000 [00:35<02:21, 23.85 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:  15% 618/4000 [00:35<02:24, 23.41 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:  16% 622/4000 [00:35<02:32, 22.21 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:  16% 626/4000 [00:35<02:35, 21.71 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:  16% 630/4000 [00:35<02:31, 22.31 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:  16% 634/4000 [00:36<02:35, 21.67 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:  16% 638/4000 [00:36<02:46, 20.24 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:  16% 642/4000 [00:36<02:44, 20.38 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:  16% 646/4000 [00:36<02:35, 21.54 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:  16% 650/4000 [00:36<02:28, 22.54 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:  16% 654/4000 [00:36<02:31, 22.10 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:  16% 658/4000 [00:37<02:20, 23.85 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:  17% 662/4000 [00:37<02:25, 23.00 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:  17% 666/4000 [00:37<02:39, 20.88 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:  17% 670/4000 [00:37<02:24, 23.05 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:  17% 674/4000 [00:37<02:27, 22.59 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:  17% 678/4000 [00:38<02:22, 23.27 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:  17% 682/4000 [00:38<02:11, 25.28 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:  17% 686/4000 [00:38<02:12, 25.08 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:  17% 690/4000 [00:38<02:18, 23.90 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:  17% 694/4000 [00:38<02:08, 25.64 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:  17% 698/4000 [00:38<02:01, 27.20 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:  18% 702/4000 [00:38<02:00, 27.30 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:  18% 706/4000 [00:39<02:05, 26.21 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:  18% 710/4000 [00:39<02:25, 22.62 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:  18% 714/4000 [00:39<02:45, 19.82 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:  18% 718/4000 [00:39<02:26, 22.39 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:  18% 722/4000 [00:39<02:19, 23.44 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:  18% 726/4000 [00:39<02:08, 25.41 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:  18% 730/4000 [00:40<02:00, 27.14 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:  18% 734/4000 [00:40<01:54, 28.58 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:  18% 738/4000 [00:40<01:58, 27.58 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:  19% 742/4000 [00:40<02:06, 25.67 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:  19% 746/4000 [00:40<02:11, 24.78 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:  19% 750/4000 [00:40<02:36, 20.78 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:  19% 754/4000 [00:41<02:43, 19.86 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:  19% 758/4000 [00:41<02:48, 19.29 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:  19% 762/4000 [00:41<02:53, 18.62 examples/s]Using default parameters optimized on Brouhaha
# Map:  19% 764/4000 [00:41<02:57, 18.21 examples/s]Using default parameters optimized on Brouhaha
# Map:  19% 766/4000 [00:41<03:03, 17.65 examples/s]Using default parameters optimized on Brouhaha
# Map:  19% 768/4000 [00:42<03:29, 15.40 examples/s]Using default parameters optimized on Brouhaha
# Map:  19% 770/4000 [00:42<03:49, 14.05 examples/s]Using default parameters optimized on Brouhaha
# Map:  19% 772/4000 [00:42<03:52, 13.88 examples/s]Using default parameters optimized on Brouhaha
# Map:  19% 774/4000 [00:42<03:48, 14.15 examples/s]Using default parameters optimized on Brouhaha
# Map:  19% 776/4000 [00:42<03:29, 15.39 examples/s]Using default parameters optimized on Brouhaha
# Map:  19% 778/4000 [00:42<03:17, 16.34 examples/s]Using default parameters optimized on Brouhaha
# Map:  20% 780/4000 [00:42<03:29, 15.35 examples/s]Using default parameters optimized on Brouhaha
# Map:  20% 782/4000 [00:43<03:37, 14.78 examples/s]Using default parameters optimized on Brouhaha
# Map:  20% 784/4000 [00:43<04:07, 13.02 examples/s]Using default parameters optimized on Brouhaha
# Map:  20% 786/4000 [00:43<03:57, 13.51 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:  20% 790/4000 [00:43<03:20, 16.01 examples/s]Using default parameters optimized on Brouhaha
# Map:  20% 792/4000 [00:43<03:26, 15.53 examples/s]Using default parameters optimized on Brouhaha
# Map:  20% 794/4000 [00:43<03:57, 13.52 examples/s]Using default parameters optimized on Brouhaha
# Map:  20% 796/4000 [00:44<04:26, 12.00 examples/s]Using default parameters optimized on Brouhaha
# Map:  20% 798/4000 [00:44<04:27, 11.96 examples/s]Using default parameters optimized on Brouhaha
# Map:  20% 800/4000 [00:44<04:15, 12.55 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:  20% 804/4000 [00:44<03:28, 15.35 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:  20% 808/4000 [00:44<03:18, 16.04 examples/s]Using default parameters optimized on Brouhaha
# Map:  20% 810/4000 [00:45<03:18, 16.09 examples/s]Using default parameters optimized on Brouhaha
# Map:  20% 812/4000 [00:45<03:10, 16.73 examples/s]Using default parameters optimized on Brouhaha
# Map:  20% 814/4000 [00:45<03:19, 15.97 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:  20% 818/4000 [00:45<02:59, 17.74 examples/s]Using default parameters optimized on Brouhaha
# Map:  20% 820/4000 [00:45<03:00, 17.57 examples/s]Using default parameters optimized on Brouhaha
# Map:  21% 822/4000 [00:45<02:56, 18.02 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:  21% 826/4000 [00:45<02:57, 17.91 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:  21% 830/4000 [00:46<02:51, 18.43 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:  21% 834/4000 [00:46<02:50, 18.52 examples/s]Using default parameters optimized on Brouhaha
# Map:  21% 836/4000 [00:46<02:58, 17.75 examples/s]Using default parameters optimized on Brouhaha
# Map:  21% 838/4000 [00:46<03:09, 16.69 examples/s]Using default parameters optimized on Brouhaha
# Map:  21% 840/4000 [00:46<03:08, 16.74 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:  21% 844/4000 [00:46<02:52, 18.32 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:  21% 848/4000 [00:47<02:37, 19.97 examples/s]Using default parameters optimized on Brouhaha
# Map:  21% 850/4000 [00:47<02:38, 19.88 examples/s]Using default parameters optimized on Brouhaha
# Map:  21% 852/4000 [00:47<02:42, 19.38 examples/s]Using default parameters optimized on Brouhaha
# Map:  21% 854/4000 [00:47<02:44, 19.08 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:  21% 858/4000 [00:47<02:47, 18.76 examples/s]Using default parameters optimized on Brouhaha
# Map:  22% 860/4000 [00:47<02:55, 17.86 examples/s]Using default parameters optimized on Brouhaha
# Map:  22% 862/4000 [00:47<03:01, 17.29 examples/s]Using default parameters optimized on Brouhaha
# Map:  22% 864/4000 [00:47<03:07, 16.75 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:  22% 868/4000 [00:48<03:04, 16.94 examples/s]Using default parameters optimized on Brouhaha
# Map:  22% 870/4000 [00:48<03:22, 15.49 examples/s]Using default parameters optimized on Brouhaha
# Map:  22% 872/4000 [00:48<03:12, 16.25 examples/s]Using default parameters optimized on Brouhaha
# Map:  22% 874/4000 [00:48<03:05, 16.89 examples/s]Using default parameters optimized on Brouhaha
# Map:  22% 876/4000 [00:48<03:02, 17.09 examples/s]Using default parameters optimized on Brouhaha
# Map:  22% 878/4000 [00:48<02:55, 17.81 examples/s]Using default parameters optimized on Brouhaha
# Map:  22% 880/4000 [00:48<03:03, 16.97 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:  22% 884/4000 [00:49<02:28, 20.93 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:  22% 888/4000 [00:49<02:39, 19.51 examples/s]Using default parameters optimized on Brouhaha
# Map:  22% 890/4000 [00:49<02:51, 18.16 examples/s]Using default parameters optimized on Brouhaha
# Map:  22% 892/4000 [00:49<02:59, 17.30 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:  22% 896/4000 [00:49<02:46, 18.69 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:  22% 900/4000 [00:49<02:38, 19.56 examples/s]Using default parameters optimized on Brouhaha
# Map:  23% 902/4000 [00:50<02:39, 19.42 examples/s]Using default parameters optimized on Brouhaha
# Map:  23% 904/4000 [00:50<02:46, 18.56 examples/s]Using default parameters optimized on Brouhaha
# Map:  23% 906/4000 [00:50<03:05, 16.68 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:  23% 910/4000 [00:50<02:41, 19.10 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:  23% 914/4000 [00:50<02:39, 19.37 examples/s]Using default parameters optimized on Brouhaha
# Map:  23% 916/4000 [00:50<02:46, 18.57 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:  23% 920/4000 [00:50<02:29, 20.60 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:  23% 924/4000 [00:51<02:29, 20.64 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:  23% 928/4000 [00:51<02:48, 18.23 examples/s]Using default parameters optimized on Brouhaha
# Map:  23% 930/4000 [00:51<02:52, 17.82 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:  23% 934/4000 [00:51<02:37, 19.52 examples/s]Using default parameters optimized on Brouhaha
# Map:  23% 936/4000 [00:51<02:42, 18.87 examples/s]Using default parameters optimized on Brouhaha
# Map:  23% 938/4000 [00:51<02:51, 17.89 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:  24% 942/4000 [00:52<02:49, 18.03 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:  24% 946/4000 [00:52<02:54, 17.51 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:  24% 950/4000 [00:52<02:46, 18.36 examples/s]Using default parameters optimized on Brouhaha
# Map:  24% 952/4000 [00:52<02:43, 18.59 examples/s]Using default parameters optimized on Brouhaha
# Map:  24% 954/4000 [00:52<02:49, 17.98 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:  24% 958/4000 [00:53<02:30, 20.18 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:  24% 962/4000 [00:53<02:48, 18.04 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:  24% 966/4000 [00:53<02:39, 19.07 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:  24% 970/4000 [00:53<02:25, 20.83 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:  24% 974/4000 [00:53<02:24, 20.95 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:  24% 978/4000 [00:54<02:31, 19.94 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:  25% 982/4000 [00:54<02:29, 20.21 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:  25% 986/4000 [00:54<03:06, 16.13 examples/s]Using default parameters optimized on Brouhaha
# Map:  25% 988/4000 [00:54<03:16, 15.35 examples/s]Using default parameters optimized on Brouhaha
# Map:  25% 990/4000 [00:54<03:20, 15.03 examples/s]Using default parameters optimized on Brouhaha
# Map:  25% 992/4000 [00:55<03:33, 14.07 examples/s]Using default parameters optimized on Brouhaha
# Map:  25% 994/4000 [00:55<03:32, 14.13 examples/s]Using default parameters optimized on Brouhaha
# ...
# Map:  92% 3690/4000 [03:26<00:23, 13.34 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:  92% 3694/4000 [03:27<00:18, 16.41 examples/s]Using default parameters optimized on Brouhaha
# Map:  92% 3696/4000 [03:27<00:19, 15.88 examples/s]Using default parameters optimized on Brouhaha
# Map:  92% 3698/4000 [03:27<00:18, 16.41 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:  93% 3702/4000 [03:27<00:18, 16.53 examples/s]Using default parameters optimized on Brouhaha
# Map:  93% 3704/4000 [03:27<00:18, 15.89 examples/s]Using default parameters optimized on Brouhaha
# Map:  93% 3706/4000 [03:27<00:17, 16.68 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:  93% 3710/4000 [03:27<00:16, 17.09 examples/s]Using default parameters optimized on Brouhaha
# Map:  93% 3712/4000 [03:28<00:16, 17.60 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:  93% 3716/4000 [03:28<00:15, 18.74 examples/s]Using default parameters optimized on Brouhaha
# Map:  93% 3718/4000 [03:28<00:15, 17.86 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:  93% 3722/4000 [03:28<00:14, 19.02 examples/s]Using default parameters optimized on Brouhaha
# Map:  93% 3724/4000 [03:28<00:15, 17.52 examples/s]Using default parameters optimized on Brouhaha
# Map:  93% 3726/4000 [03:28<00:15, 17.23 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:  93% 3730/4000 [03:29<00:14, 18.17 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:  93% 3734/4000 [03:29<00:14, 18.78 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:  93% 3738/4000 [03:29<00:14, 18.39 examples/s]Using default parameters optimized on Brouhaha
# Map:  94% 3740/4000 [03:29<00:14, 17.68 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:  94% 3744/4000 [03:29<00:13, 18.97 examples/s]Using default parameters optimized on Brouhaha
# Map:  94% 3746/4000 [03:29<00:13, 18.92 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:  94% 3750/4000 [03:30<00:13, 18.38 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:  94% 3754/4000 [03:30<00:12, 19.38 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:  94% 3758/4000 [03:30<00:12, 19.66 examples/s]Using default parameters optimized on Brouhaha
# Map:  94% 3760/4000 [03:30<00:12, 19.40 examples/s]Using default parameters optimized on Brouhaha
# Map:  94% 3762/4000 [03:30<00:12, 18.34 examples/s]Using default parameters optimized on Brouhaha
# Map:  94% 3764/4000 [03:30<00:13, 17.52 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:  94% 3768/4000 [03:31<00:11, 20.07 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:  94% 3772/4000 [03:31<00:11, 20.50 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:  94% 3776/4000 [03:31<00:11, 19.97 examples/s]Using default parameters optimized on Brouhaha
# Map:  94% 3778/4000 [03:31<00:11, 19.48 examples/s]Using default parameters optimized on Brouhaha
# Map:  94% 3780/4000 [03:31<00:12, 18.23 examples/s]Using default parameters optimized on Brouhaha
# Map:  95% 3782/4000 [03:31<00:12, 18.01 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:  95% 3786/4000 [03:32<00:11, 18.37 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:  95% 3790/4000 [03:32<00:11, 18.43 examples/s]Using default parameters optimized on Brouhaha
# Map:  95% 3792/4000 [03:32<00:11, 17.59 examples/s]Using default parameters optimized on Brouhaha
# Map:  95% 3794/4000 [03:32<00:11, 17.82 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:  95% 3798/4000 [03:32<00:10, 18.80 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:  95% 3802/4000 [03:32<00:10, 18.32 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:  95% 3806/4000 [03:33<00:09, 20.90 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:  95% 3810/4000 [03:33<00:08, 22.04 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:  95% 3814/4000 [03:33<00:08, 22.90 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:  95% 3818/4000 [03:33<00:07, 22.83 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:  96% 3822/4000 [03:33<00:07, 23.36 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:  96% 3826/4000 [03:33<00:08, 19.54 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:  96% 3830/4000 [03:34<00:08, 19.91 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:  96% 3834/4000 [03:34<00:08, 19.87 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:  96% 3838/4000 [03:34<00:08, 19.71 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:  96% 3842/4000 [03:34<00:07, 20.77 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:  96% 3846/4000 [03:34<00:07, 21.24 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:  96% 3850/4000 [03:35<00:07, 20.65 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:  96% 3854/4000 [03:35<00:07, 20.85 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:  96% 3858/4000 [03:35<00:06, 22.71 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:  97% 3862/4000 [03:35<00:05, 23.02 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:  97% 3866/4000 [03:35<00:05, 23.70 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:  97% 3870/4000 [03:36<00:05, 21.76 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:  97% 3874/4000 [03:36<00:05, 22.41 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:  97% 3878/4000 [03:36<00:05, 20.89 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:  97% 3882/4000 [03:36<00:05, 20.71 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:  97% 3886/4000 [03:36<00:04, 23.40 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:  97% 3890/4000 [03:36<00:05, 20.49 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:  97% 3894/4000 [03:37<00:05, 18.98 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:  97% 3898/4000 [03:37<00:06, 16.97 examples/s]Using default parameters optimized on Brouhaha
# Map:  98% 3900/4000 [03:37<00:05, 16.67 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:  98% 3904/4000 [03:37<00:05, 17.14 examples/s]Using default parameters optimized on Brouhaha
# Map:  98% 3906/4000 [03:38<00:05, 16.58 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:  98% 3910/4000 [03:38<00:05, 17.19 examples/s]Using default parameters optimized on Brouhaha
# Map:  98% 3912/4000 [03:38<00:06, 14.60 examples/s]Using default parameters optimized on Brouhaha
# Map:  98% 3914/4000 [03:38<00:05, 15.41 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:  98% 3918/4000 [03:38<00:04, 16.98 examples/s]Using default parameters optimized on Brouhaha
# Map:  98% 3920/4000 [03:38<00:05, 15.74 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:  98% 3924/4000 [03:39<00:04, 16.89 examples/s]Using default parameters optimized on Brouhaha
# Map:  98% 3926/4000 [03:39<00:04, 16.56 examples/s]Using default parameters optimized on Brouhaha
# Map:  98% 3928/4000 [03:39<00:04, 17.15 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:  98% 3932/4000 [03:39<00:03, 20.13 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:  98% 3936/4000 [03:39<00:02, 23.19 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:  98% 3940/4000 [03:39<00:02, 23.52 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:  99% 3944/4000 [03:39<00:02, 24.09 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:  99% 3948/4000 [03:40<00:02, 20.99 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:  99% 3952/4000 [03:40<00:02, 21.14 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:  99% 3956/4000 [03:40<00:02, 20.62 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:  99% 3960/4000 [03:40<00:01, 22.80 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:  99% 3964/4000 [03:40<00:01, 22.10 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:  99% 3968/4000 [03:41<00:01, 22.90 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:  99% 3972/4000 [03:41<00:01, 22.91 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:  99% 3976/4000 [03:41<00:01, 22.91 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map: 100% 3980/4000 [03:41<00:00, 21.18 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map: 100% 3984/4000 [03:41<00:00, 21.63 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map: 100% 3988/4000 [03:41<00:00, 22.38 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map: 100% 3992/4000 [03:42<00:00, 21.63 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map: 100% 3996/4000 [03:42<00:00, 21.87 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map: 100% 4000/4000 [03:42<00:00, 17.97 examples/s]
# Compute speaking rate
# Map (num_proc=2):   0% 0/4000 [00:00<?, ? examples/s]2025-03-12 05:31:42.526536: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2025-03-12 05:31:42.542136: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1741757502.560952    6122 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1741757502.571504    6122 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1741757502.610681    6127 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1741757502.636099    6127 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-03-12 05:31:42.690092: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1741757502.727741    6123 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1741757502.739523    6123 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# INFO - Applied quirks (see `speechbrain.utils.quirks`): [allow_tf32, disable_jit_profiling]
# INFO - Excluded quirks specified by the `SB_DISABLE_QUIRKS` environment (comma-separated list): []
# /usr/local/lib/python3.11/dist-packages/pyannote/audio/pipelines/speaker_verification.py:43: UserWarning: Module 'speechbrain.pretrained' was deprecated, redirecting to 'speechbrain.inference'. Please update your script. This is a change from SpeechBrain 1.0. See: https://github.com/speechbrain/speechbrain/releases/tag/v1.0.0
#   from speechbrain.pretrained import (
# INFO - Applied quirks (see `speechbrain.utils.quirks`): [disable_jit_profiling, allow_tf32]
# INFO - Excluded quirks specified by the `SB_DISABLE_QUIRKS` environment (comma-separated list): []
# /usr/local/lib/python3.11/dist-packages/pyannote/audio/pipelines/speaker_verification.py:43: UserWarning: Module 'speechbrain.pretrained' was deprecated, redirecting to 'speechbrain.inference'. Please update your script. This is a change from SpeechBrain 1.0. See: https://github.com/speechbrain/speechbrain/releases/tag/v1.0.0
#   from speechbrain.pretrained import (
# INFO - Applied quirks (see `speechbrain.utils.quirks`): [allow_tf32, disable_jit_profiling]
# INFO - Excluded quirks specified by the `SB_DISABLE_QUIRKS` environment (comma-separated list): []
# /usr/local/lib/python3.11/dist-packages/pyannote/audio/pipelines/speaker_verification.py:43: UserWarning: Module 'speechbrain.pretrained' was deprecated, redirecting to 'speechbrain.inference'. Please update your script. This is a change from SpeechBrain 1.0. See: https://github.com/speechbrain/speechbrain/releases/tag/v1.0.0
#   from speechbrain.pretrained import (
# Map (num_proc=2): 100% 4000/4000 [00:38<00:00, 103.02 examples/s]
# Pushing to the hub...
# Uploading the dataset shards:   0% 0/1 [00:00<?, ?it/s]
# Creating parquet from Arrow format:   0% 0/4 [00:00<?, ?ba/s]
# Creating parquet from Arrow format: 100% 4/4 [00:00<00:00, 31.53ba/s]
# Uploading the dataset shards: 100% 1/1 [00:02<00:00,  2.64s/it]

# %% [markdown]
# The whole process took under 10mn!
#
# The resulting dataset will be pushed to the HuggingFace hub under your HuggingFace handle. Mine was push to [ylacombe/jenny-tts-tags-6h](https://huggingface.co/datasets/ylacombe/jenny-tts-tags-6h).
#
# Let's see what the new dataset looks like:

# %%
from datasets import load_dataset
dataset = load_dataset("hijklmno/jenny-tts-tags-6h")
print("SNR 1st sample", dataset["train"][0]["snr"])
print("C50 2nd sample", dataset["train"][0]["c50"])
del dataset
# Out:
# README.md:   0%|          | 0.00/609 [00:00<?, ?B/s]
# train-00000-of-00001.parquet:   0%|          | 0.00/952k [00:00<?, ?B/s]
# Generating train split:   0%|          | 0/4000 [00:00<?, ? examples/s]
# SNR 1st sample 54.58160400390625
# C50 2nd sample 59.780765533447266

# %% [markdown]
# As you can see, the current annotations are continuous variables. To use it with Parler-TTS, we need to convert it to textual description, something that the two next steps will take care of.

# %% [markdown]
# ### 2. Map annotations to text bins
#
# Since the ultimate goal here is to fine-tune the [Parler-TTS v0.1 checkpoint](https://huggingface.co/parler-tts/parler_tts_mini_v0.1) on the Jenny dataset, we want to stay consistent with the text bins of the datasets on which the latter model was trained.
#
# This is easy to do thanks to the following:

# %%
# !python ./scripts/metadata_to_text.py \
    "hijklmno/jenny-tts-tags-6h" \
    --repo_id "jenny-tts-tags-6h" \
    --configuration "default" \
    --cpu_num_workers 2 \
    --path_to_bin_edges "./examples/tags_to_annotations/v01_bin_edges.json" \
    --avoid_pitch_computation
# Out:
# Already computed bin edges have been passed for speaking_rate. Will use: [3.508771929824561, 6.187242299296628, 8.865712668768696, 11.544183038240764, 14.22265340771283, 16.901123777184896, 19.579594146656966, 22.258064516129032].
# Map (num_proc=2): 100% 4000/4000 [00:03<00:00, 1102.82 examples/s]
# Already computed bin edges have been passed for noise. Will use: [27.179607391357422, 33.90050179617746, 40.62139620099749, 47.342290605817524, 54.063185010637554, 60.78407941545759, 67.50497382027763, 74.22586822509766].
# Map (num_proc=2): 100% 4000/4000 [00:03<00:00, 1096.02 examples/s]
# Already computed bin edges have been passed for reverberation. Will use: [30.498437881469727, 34.706024169921875, 38.91361045837402, 43.12119674682617, 47.32878303527832, 51.53636932373047, 55.74395561218262, 59.951541900634766].
# Map (num_proc=2): 100% 4000/4000 [00:04<00:00, 848.35 examples/s]
# Already computed bin edges have been passed for speech_monotony. Will use: [0.0, 17.430070059640066, 34.86014011928013, 52.2902101789202, 69.72028023856026, 87.15035029820032, 104.5804203578404, 122.01049041748047].
# Map (num_proc=2): 100% 4000/4000 [00:03<00:00, 1115.81 examples/s]
# Uploading the dataset shards:   0% 0/1 [00:00<?, ?it/s]
# Creating parquet from Arrow format: 100% 4/4 [00:00<00:00, 138.23ba/s]
# Uploading the dataset shards: 100% 1/1 [00:01<00:00,  1.21s/it]

# %% [markdown]
# Thanks to [`v01_bin_edges.json`](https://github.com/huggingface/dataspeech/blob/main/examples/tags_to_annotations/v01_bin_edges.json), we don't need to recompute bins from scratch and the above script takes a few seconds.
#
# The resulting dataset will be pushed to the HuggingFace hub under your HuggingFace handle. Mine was push to [ylacombe/jenny-tts-tags-6h](https://huggingface.co/datasets/ylacombe/jenny-tts-tags-6h).
#
# You can notice that text bins such as `quite noisy`, `very fast` have been added to the samples.

# %%
from datasets import load_dataset
dataset = load_dataset("hijklmno/jenny-tts-tags-6h")
print("Noise 1st sample:", dataset["train"][0]["noise"])
print("Speaking rate 2nd sample:", dataset["train"][0]["speaking_rate"])
del dataset
# Out:
# README.md:   0%|          | 0.00/728 [00:00<?, ?B/s]
# train-00000-of-00001.parquet:   0%|          | 0.00/928k [00:00<?, ?B/s]
# Generating train split:   0%|          | 0/4000 [00:00<?, ? examples/s]
# Noise 1st sample: slightly clear
# Speaking rate 2nd sample: quite fast

# %% [markdown]
# ### 3. Create natural language descriptions from those text bins
#
# Now that we have text bins associated to the Jenny dataset, the next step is to create natural language descriptions out of the few created features.
#
# Here, we decided to create prompts that use the name `Jenny`, prompts that'll look like the following:
# `In a very expressive voice, Jenny pronounces her words incredibly slowly. There's some background noise in this room with a bit of echo'`
#
# This step generally demands more resources and times and should use one or many GPUs.
#
# The following command shows how to do it using the [2B version of the Gemma model from Google](https://huggingface.co/google/gemma-2b-it), which should run in about 15 minutes in this Colab free T4.
#
#
# As usual, we precise the dataset name and configuration we want to annotate. `model_name_or_path` should point to a `transformers` model for prompt annotation. You can find a list of such models [here](https://huggingface.co/models?pipeline_tag=text-generation&library=transformers&sort=trending).
#
# **Note** how we've been able to specify that the dataset is mono-speaker and that we should name the voice Jenny thanks to the flags:
#
#
# `--speaker_name "Jenny" --is_single_speaker`.

# %%
# !python ./scripts/run_prompt_creation.py \
  --speaker_name "Jenny" \
  --is_single_speaker \
  --dataset_name "hijklmno/jenny-tts-tags-6h" \
  --output_dir "./tmp_jenny" \
  --dataset_config_name "default" \
  --model_name_or_path "google/gemma-2b-it" \
  --per_device_eval_batch_size 12 \
  --attn_implementation "sdpa" \
  --dataloader_num_workers 2 \
  --push_to_hub \
  --hub_dataset_id "jenny-tts-6h-tagged" \
  --preprocessing_num_workers 2
# Out:
# 03/12/2025 05:36:11 - INFO - __main__ - *** Load annotated dataset ***
# 03/12/2025 05:36:15 - INFO - __main__ - *** Load pretrained model ***
# config.json: 100% 627/627 [00:00<00:00, 4.61MB/s]
# 2025-03-12 05:36:18.977800: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1741757779.000129    7483 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1741757779.006555    7483 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-03-12 05:36:19.028966: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# model.safetensors.index.json: 100% 13.5k/13.5k [00:00<00:00, 58.8MB/s]
# Downloading shards:   0% 0/2 [00:00<?, ?it/s]
# model-00001-of-00002.safetensors:   0% 0.00/4.95G [00:00<?, ?B/s]
# model-00001-of-00002.safetensors:   0% 21.0M/4.95G [00:00<00:25, 191MB/s]
# model-00001-of-00002.safetensors:   1% 52.4M/4.95G [00:00<00:22, 217MB/s]
# model-00001-of-00002.safetensors:   2% 83.9M/4.95G [00:00<00:21, 227MB/s]
# model-00001-of-00002.safetensors:   2% 115M/4.95G [00:00<00:21, 229MB/s]
# model-00001-of-00002.safetensors:   3% 147M/4.95G [00:00<00:22, 217MB/s]
# model-00001-of-00002.safetensors:   4% 178M/4.95G [00:00<00:21, 221MB/s]
# model-00001-of-00002.safetensors:   4% 210M/4.95G [00:00<00:21, 217MB/s]
# model-00001-of-00002.safetensors:   5% 241M/4.95G [00:01<00:21, 223MB/s]
# model-00001-of-00002.safetensors:   6% 273M/4.95G [00:01<00:20, 229MB/s]
# model-00001-of-00002.safetensors:   6% 304M/4.95G [00:01<00:19, 233MB/s]
# model-00001-of-00002.safetensors:   7% 336M/4.95G [00:01<00:19, 234MB/s]
# model-00001-of-00002.safetensors:   7% 367M/4.95G [00:01<00:19, 235MB/s]
# model-00001-of-00002.safetensors:   8% 398M/4.95G [00:01<00:20, 226MB/s]
# model-00001-of-00002.safetensors:   9% 430M/4.95G [00:01<00:19, 231MB/s]
# model-00001-of-00002.safetensors:   9% 461M/4.95G [00:02<00:19, 233MB/s]
# model-00001-of-00002.safetensors:  10% 493M/4.95G [00:02<00:19, 226MB/s]
# model-00001-of-00002.safetensors:  11% 524M/4.95G [00:02<00:19, 228MB/s]
# model-00001-of-00002.safetensors:  11% 556M/4.95G [00:02<00:18, 234MB/s]
# model-00001-of-00002.safetensors:  12% 587M/4.95G [00:02<00:18, 235MB/s]
# model-00001-of-00002.safetensors:  13% 619M/4.95G [00:02<00:18, 240MB/s]
# model-00001-of-00002.safetensors:  13% 650M/4.95G [00:02<00:18, 237MB/s]
# model-00001-of-00002.safetensors:  14% 682M/4.95G [00:02<00:17, 238MB/s]
# model-00001-of-00002.safetensors:  14% 713M/4.95G [00:03<00:17, 238MB/s]
# model-00001-of-00002.safetensors:  15% 744M/4.95G [00:03<00:17, 236MB/s]
# model-00001-of-00002.safetensors:  16% 776M/4.95G [00:03<00:17, 235MB/s]
# model-00001-of-00002.safetensors:  16% 807M/4.95G [00:03<00:17, 236MB/s]
# model-00001-of-00002.safetensors:  17% 839M/4.95G [00:03<00:17, 239MB/s]
# model-00001-of-00002.safetensors:  18% 870M/4.95G [00:03<00:17, 239MB/s]
# model-00001-of-00002.safetensors:  18% 902M/4.95G [00:03<00:16, 243MB/s]
# model-00001-of-00002.safetensors:  19% 933M/4.95G [00:04<00:16, 240MB/s]
# model-00001-of-00002.safetensors:  20% 965M/4.95G [00:04<00:16, 242MB/s]
# model-00001-of-00002.safetensors:  20% 996M/4.95G [00:04<00:16, 243MB/s]
# model-00001-of-00002.safetensors:  21% 1.03G/4.95G [00:04<00:16, 241MB/s]
# model-00001-of-00002.safetensors:  21% 1.06G/4.95G [00:04<00:18, 210MB/s]
# model-00001-of-00002.safetensors:  22% 1.09G/4.95G [00:04<00:17, 217MB/s]
# model-00001-of-00002.safetensors:  23% 1.12G/4.95G [00:04<00:17, 221MB/s]
# model-00001-of-00002.safetensors:  23% 1.15G/4.95G [00:05<00:17, 223MB/s]
# model-00001-of-00002.safetensors:  24% 1.18G/4.95G [00:05<00:17, 220MB/s]
# model-00001-of-00002.safetensors:  25% 1.22G/4.95G [00:05<00:16, 225MB/s]
# model-00001-of-00002.safetensors:  25% 1.25G/4.95G [00:05<00:16, 224MB/s]
# model-00001-of-00002.safetensors:  26% 1.28G/4.95G [00:05<00:18, 195MB/s]
# model-00001-of-00002.safetensors:  27% 1.31G/4.95G [00:05<00:17, 207MB/s]
# model-00001-of-00002.safetensors:  27% 1.34G/4.95G [00:05<00:17, 200MB/s]
# model-00001-of-00002.safetensors:  28% 1.37G/4.95G [00:06<00:17, 206MB/s]
# model-00001-of-00002.safetensors:  28% 1.41G/4.95G [00:06<00:16, 214MB/s]
# model-00001-of-00002.safetensors:  29% 1.44G/4.95G [00:06<00:16, 219MB/s]
# model-00001-of-00002.safetensors:  30% 1.47G/4.95G [00:08<01:28, 39.2MB/s]
# model-00001-of-00002.safetensors:  30% 1.50G/4.95G [00:08<01:04, 53.2MB/s]
# model-00001-of-00002.safetensors:  31% 1.53G/4.95G [00:08<00:49, 69.2MB/s]
# model-00001-of-00002.safetensors:  32% 1.56G/4.95G [00:09<00:38, 87.6MB/s]
# model-00001-of-00002.safetensors:  32% 1.59G/4.95G [00:09<00:30, 108MB/s]
# model-00001-of-00002.safetensors:  33% 1.63G/4.95G [00:09<00:25, 130MB/s]
# model-00001-of-00002.safetensors:  34% 1.66G/4.95G [00:09<00:21, 151MB/s]
# model-00001-of-00002.safetensors:  34% 1.69G/4.95G [00:09<00:19, 170MB/s]
# model-00001-of-00002.safetensors:  35% 1.72G/4.95G [00:09<00:17, 186MB/s]
# model-00001-of-00002.safetensors:  35% 1.75G/4.95G [00:09<00:15, 202MB/s]
# model-00001-of-00002.safetensors:  36% 1.78G/4.95G [00:09<00:15, 209MB/s]
# model-00001-of-00002.safetensors:  37% 1.81G/4.95G [00:10<00:16, 189MB/s]
# model-00001-of-00002.safetensors:  37% 1.85G/4.95G [00:10<00:15, 196MB/s]
# model-00001-of-00002.safetensors:  38% 1.88G/4.95G [00:10<00:14, 208MB/s]
# model-00001-of-00002.safetensors:  39% 1.91G/4.95G [00:10<00:13, 218MB/s]
# model-00001-of-00002.safetensors:  39% 1.94G/4.95G [00:10<00:13, 227MB/s]
# model-00001-of-00002.safetensors:  40% 1.97G/4.95G [00:10<00:12, 229MB/s]
# model-00001-of-00002.safetensors:  40% 2.00G/4.95G [00:14<02:00, 24.3MB/s]
# model-00001-of-00002.safetensors:  41% 2.03G/4.95G [00:14<01:26, 33.5MB/s]
# model-00001-of-00002.safetensors:  42% 2.07G/4.95G [00:15<01:03, 45.1MB/s]
# model-00001-of-00002.safetensors:  42% 2.10G/4.95G [00:15<00:47, 59.5MB/s]
# model-00001-of-00002.safetensors:  43% 2.13G/4.95G [00:15<00:37, 76.0MB/s]
# model-00001-of-00002.safetensors:  44% 2.16G/4.95G [00:15<00:28, 97.1MB/s]
# model-00001-of-00002.safetensors:  44% 2.19G/4.95G [00:15<00:23, 117MB/s]
# model-00001-of-00002.safetensors:  45% 2.22G/4.95G [00:15<00:19, 139MB/s]
# model-00001-of-00002.safetensors:  46% 2.25G/4.95G [00:15<00:16, 159MB/s]
# model-00001-of-00002.safetensors:  46% 2.29G/4.95G [00:16<00:15, 176MB/s]
# model-00001-of-00002.safetensors:  47% 2.32G/4.95G [00:16<00:13, 193MB/s]
# model-00001-of-00002.safetensors:  47% 2.35G/4.95G [00:16<00:12, 204MB/s]
# model-00001-of-00002.safetensors:  48% 2.38G/4.95G [00:16<00:11, 216MB/s]
# model-00001-of-00002.safetensors:  49% 2.41G/4.95G [00:16<00:11, 224MB/s]
# model-00001-of-00002.safetensors:  49% 2.44G/4.95G [00:16<00:10, 230MB/s]
# model-00001-of-00002.safetensors:  50% 2.47G/4.95G [00:16<00:10, 235MB/s]
# model-00001-of-00002.safetensors:  51% 2.51G/4.95G [00:16<00:10, 238MB/s]
# model-00001-of-00002.safetensors:  51% 2.54G/4.95G [00:17<00:10, 238MB/s]
# model-00001-of-00002.safetensors:  52% 2.57G/4.95G [00:17<00:10, 235MB/s]
# model-00001-of-00002.safetensors:  53% 2.60G/4.95G [00:17<00:09, 236MB/s]
# model-00001-of-00002.safetensors:  53% 2.63G/4.95G [00:17<00:09, 241MB/s]
# model-00001-of-00002.safetensors:  54% 2.66G/4.95G [00:17<00:09, 233MB/s]
# model-00001-of-00002.safetensors:  54% 2.69G/4.95G [00:17<00:09, 240MB/s]
# model-00001-of-00002.safetensors:  55% 2.73G/4.95G [00:17<00:09, 242MB/s]
# model-00001-of-00002.safetensors:  56% 2.76G/4.95G [00:17<00:09, 232MB/s]
# model-00001-of-00002.safetensors:  56% 2.79G/4.95G [00:18<00:08, 243MB/s]
# model-00001-of-00002.safetensors:  57% 2.82G/4.95G [00:18<00:09, 229MB/s]
# model-00001-of-00002.safetensors:  58% 2.85G/4.95G [00:18<00:08, 249MB/s]
# model-00001-of-00002.safetensors:  58% 2.88G/4.95G [00:18<00:08, 235MB/s]
# model-00001-of-00002.safetensors:  59% 2.92G/4.95G [00:18<00:08, 251MB/s]
# model-00001-of-00002.safetensors:  60% 2.95G/4.95G [00:18<00:08, 246MB/s]
# model-00001-of-00002.safetensors:  60% 2.98G/4.95G [00:18<00:08, 219MB/s]
# model-00001-of-00002.safetensors:  61% 3.01G/4.95G [00:19<00:09, 215MB/s]
# model-00001-of-00002.safetensors:  61% 3.04G/4.95G [00:19<00:08, 213MB/s]
# model-00001-of-00002.safetensors:  62% 3.07G/4.95G [00:19<00:08, 226MB/s]
# model-00001-of-00002.safetensors:  63% 3.10G/4.95G [00:19<00:08, 229MB/s]
# model-00001-of-00002.safetensors:  63% 3.14G/4.95G [00:19<00:07, 242MB/s]
# model-00001-of-00002.safetensors:  64% 3.17G/4.95G [00:19<00:07, 251MB/s]
# model-00001-of-00002.safetensors:  65% 3.20G/4.95G [00:19<00:07, 240MB/s]
# model-00001-of-00002.safetensors:  65% 3.23G/4.95G [00:19<00:07, 245MB/s]
# model-00001-of-00002.safetensors:  66% 3.26G/4.95G [00:20<00:07, 230MB/s]
# model-00001-of-00002.safetensors:  67% 3.29G/4.95G [00:20<00:06, 245MB/s]
# model-00001-of-00002.safetensors:  67% 3.32G/4.95G [00:20<00:07, 222MB/s]
# model-00001-of-00002.safetensors:  68% 3.36G/4.95G [00:20<00:07, 221MB/s]
# model-00001-of-00002.safetensors:  68% 3.39G/4.95G [00:20<00:06, 227MB/s]
# model-00001-of-00002.safetensors:  69% 3.42G/4.95G [00:20<00:06, 244MB/s]
# model-00001-of-00002.safetensors:  70% 3.45G/4.95G [00:20<00:06, 246MB/s]
# model-00001-of-00002.safetensors:  70% 3.48G/4.95G [00:21<00:06, 241MB/s]
# model-00001-of-00002.safetensors:  71% 3.51G/4.95G [00:21<00:05, 244MB/s]
# model-00001-of-00002.safetensors:  72% 3.54G/4.95G [00:21<00:05, 240MB/s]
# model-00001-of-00002.safetensors:  72% 3.58G/4.95G [00:21<00:05, 238MB/s]
# model-00001-of-00002.safetensors:  73% 3.61G/4.95G [00:21<00:05, 240MB/s]
# model-00001-of-00002.safetensors:  74% 3.64G/4.95G [00:21<00:05, 244MB/s]
# model-00001-of-00002.safetensors:  74% 3.67G/4.95G [00:21<00:05, 225MB/s]
# model-00001-of-00002.safetensors:  75% 3.71G/4.95G [00:21<00:04, 249MB/s]
# model-00001-of-00002.safetensors:  76% 3.74G/4.95G [00:22<00:04, 250MB/s]
# model-00001-of-00002.safetensors:  76% 3.77G/4.95G [00:22<00:04, 250MB/s]
# model-00001-of-00002.safetensors:  77% 3.81G/4.95G [00:22<00:04, 240MB/s]
# model-00001-of-00002.safetensors:  78% 3.84G/4.95G [00:22<00:04, 251MB/s]
# model-00001-of-00002.safetensors:  78% 3.87G/4.95G [00:22<00:04, 251MB/s]
# model-00001-of-00002.safetensors:  79% 3.90G/4.95G [00:22<00:04, 247MB/s]
# model-00001-of-00002.safetensors:  80% 3.93G/4.95G [00:22<00:04, 247MB/s]
# model-00001-of-00002.safetensors:  80% 3.96G/4.95G [00:23<00:04, 241MB/s]
# model-00001-of-00002.safetensors:  81% 4.00G/4.95G [00:23<00:03, 250MB/s]
# model-00001-of-00002.safetensors:  81% 4.03G/4.95G [00:23<00:03, 247MB/s]
# model-00001-of-00002.safetensors:  82% 4.06G/4.95G [00:23<00:03, 250MB/s]
# model-00001-of-00002.safetensors:  83% 4.09G/4.95G [00:23<00:03, 252MB/s]
# model-00001-of-00002.safetensors:  83% 4.12G/4.95G [00:23<00:03, 248MB/s]
# model-00001-of-00002.safetensors:  84% 4.15G/4.95G [00:23<00:03, 239MB/s]
# model-00001-of-00002.safetensors:  85% 4.18G/4.95G [00:23<00:03, 239MB/s]
# model-00001-of-00002.safetensors:  85% 4.22G/4.95G [00:24<00:02, 245MB/s]
# model-00001-of-00002.safetensors:  86% 4.25G/4.95G [00:24<00:02, 244MB/s]
# model-00001-of-00002.safetensors:  87% 4.28G/4.95G [00:24<00:02, 246MB/s]
# model-00001-of-00002.safetensors:  87% 4.31G/4.95G [00:24<00:02, 247MB/s]
# model-00001-of-00002.safetensors:  88% 4.34G/4.95G [00:24<00:02, 246MB/s]
# model-00001-of-00002.safetensors:  88% 4.37G/4.95G [00:24<00:02, 246MB/s]
# model-00001-of-00002.safetensors:  89% 4.40G/4.95G [00:24<00:02, 246MB/s]
# model-00001-of-00002.safetensors:  90% 4.44G/4.95G [00:24<00:02, 248MB/s]
# model-00001-of-00002.safetensors:  90% 4.47G/4.95G [00:25<00:01, 246MB/s]
# model-00001-of-00002.safetensors:  91% 4.50G/4.95G [00:25<00:01, 248MB/s]
# model-00001-of-00002.safetensors:  92% 4.53G/4.95G [00:25<00:01, 245MB/s]
# model-00001-of-00002.safetensors:  92% 4.56G/4.95G [00:25<00:01, 250MB/s]
# model-00001-of-00002.safetensors:  93% 4.59G/4.95G [00:25<00:01, 247MB/s]
# model-00001-of-00002.safetensors:  94% 4.62G/4.95G [00:25<00:01, 237MB/s]
# model-00001-of-00002.safetensors:  94% 4.66G/4.95G [00:25<00:01, 248MB/s]
# model-00001-of-00002.safetensors:  95% 4.69G/4.95G [00:25<00:01, 250MB/s]
# model-00001-of-00002.safetensors:  95% 4.72G/4.95G [00:26<00:00, 248MB/s]
# model-00001-of-00002.safetensors:  96% 4.75G/4.95G [00:26<00:00, 242MB/s]
# model-00001-of-00002.safetensors:  97% 4.78G/4.95G [00:26<00:00, 246MB/s]
# model-00001-of-00002.safetensors:  97% 4.81G/4.95G [00:26<00:00, 246MB/s]
# model-00001-of-00002.safetensors:  98% 4.84G/4.95G [00:26<00:00, 240MB/s]
# model-00001-of-00002.safetensors:  99% 4.88G/4.95G [00:26<00:00, 247MB/s]
# model-00001-of-00002.safetensors:  99% 4.91G/4.95G [00:26<00:00, 244MB/s]
# model-00001-of-00002.safetensors: 100% 4.95G/4.95G [00:27<00:00, 183MB/s]
# Downloading shards:  50% 1/2 [00:27<00:27, 27.32s/it]
# model-00002-of-00002.safetensors:   0% 0.00/67.1M [00:00<?, ?B/s]
# model-00002-of-00002.safetensors:  47% 31.5M/67.1M [00:00<00:00, 247MB/s]
# model-00002-of-00002.safetensors: 100% 67.1M/67.1M [00:00<00:00, 241MB/s]
# Downloading shards: 100% 2/2 [00:27<00:00, 13.93s/it]
# `config.hidden_act` is ignored, you should use `config.hidden_activation` instead.
# Gemma's activation function will be set to `gelu_pytorch_tanh`. Please, use
# `config.hidden_activation` if you want to override this behaviour.
# See https://github.com/huggingface/transformers/pull/29402 for more details.
# Loading checkpoint shards: 100% 2/2 [00:30<00:00, 15.34s/it]
# generation_config.json: 100% 137/137 [00:00<00:00, 1.01MB/s]
# tokenizer_config.json: 100% 34.2k/34.2k [00:00<00:00, 99.3MB/s]
# tokenizer.model: 100% 4.24M/4.24M [00:00<00:00, 18.9MB/s]
# tokenizer.json: 100% 17.5M/17.5M [00:00<00:00, 120MB/s]
# special_tokens_map.json: 100% 636/636 [00:00<00:00, 4.69MB/s]
# Preparing prompts (num_proc=2): 100% 4000/4000 [00:08<00:00, 475.27 examples/s]
#  ... :   0% 0/334 [00:00<?, ?it/s]You're using a GemmaTokenizerFast tokenizer. Please note that with a fast tokenizer, using the `__call__` method is faster than using a method to encode the text followed by a call to the `pad` method to get a padded encoding.
# You're using a GemmaTokenizerFast tokenizer. Please note that with a fast tokenizer, using the `__call__` method is faster than using a method to encode the text followed by a call to the `pad` method to get a padded encoding.
#  ... : 100% 334/334 [13:36<00:00,  2.12s/it]
# Postprocessing dataset (num_proc=2):   0% 0/4000 [00:00<?, ? examples/s]
# Postprocessing dataset (num_proc=2):  25% 1000/4000 [00:16<00:49, 60.16 examples/s]
# Postprocessing dataset (num_proc=2):  50% 2000/4000 [00:17<00:14, 137.32 examples/s]
# Postprocessing dataset (num_proc=2):  50% 2000/4000 [00:27<00:14, 137.32 examples/s]
# Postprocessing dataset (num_proc=2):  75% 3000/4000 [00:28<00:09, 110.62 examples/s]
# Postprocessing dataset (num_proc=2): 100% 4000/4000 [00:29<00:00, 137.06 examples/s]
#
# Saving the dataset (0/1 shards):   0% 0/4000 [00:00<?, ? examples/s]
# Saving the dataset (1/1 shards): 100% 4000/4000 [00:00<00:00, 291965.54 examples/s]
#
# Uploading the dataset shards:   0% 0/1 [00:00<?, ?it/s]
#
# Creating parquet from Arrow format: 100% 4/4 [00:00<00:00, 288.41ba/s]
#
# Uploading the dataset shards: 100% 1/1 [00:02<00:00,  2.23s/it]
#  ... : 100% 334/334 [14:11<00:00,  2.55s/it]

# %% [markdown]
# Let's take a look at some created prompts:

# %%
from datasets import load_dataset
dataset = load_dataset("ylacombe/jenny-tts-6h-tagged")
print("1st sample:", dataset["train"][0]["text_description"])
print("2nd sample:", dataset["train"][1]["text_description"])
del dataset
# Out:
# README.md:   0%|          | 0.00/774 [00:00<?, ?B/s]
# train-00000-of-00001.parquet:   0%|          | 0.00/1.06M [00:00<?, ?B/s]
# Generating train split:   0%|          | 0/4000 [00:00<?, ? examples/s]
# 1st sample: 'The speech sample is very noisy, contains a lot of background noise, and is delivered in a monotone tone with occasional fast bursts.'
# 2nd sample: 'Jenny's speech is very noisy, but she speaks in a very monotone voice with minimal variation in speed.'.

# %% [markdown]
# **Observation:** The first sample unfortunately doesn't have the name Jenny in it. This is probably because we use a smaller and thus less precise model that one we would have gone for if this notebook had more resources (e.g we've used [Mistral 7B v2](https://huggingface.co/mistralai/Mistral-7B-Instruct-v0.2) to create the Parler-TTS training dataset). This shouldn't prevent our model to learn what we want though.

# %% [markdown]
# ## Fine-tuning Parler-TTS

# %%
# %cd ../parler-tts
# Out:
# /content/parler-tts

# %% [markdown]
# We can know fully focus on fine-tuning Parler-TTS. Luckily, [the Parler-TTS library](https://github.com/huggingface/.parler-tts) has a training script available [here](https://github.com/huggingface/parler-tts/tree/main/training), that can be used with just a few arguments.
#
#
# > **Note:** you need to enter your choice concerning WandB. If you don't have an account, you can enter `3` to avoid logging on WandB. Otherwise; you can logging to follow how your model trained.

# %%
# !accelerate launch ./training/run_parler_tts_training.py \
    --model_name_or_path "parler-tts/parler_tts_mini_v0.1" \
    --feature_extractor_name "parler-tts/dac_44khZ_8kbps" \
    --description_tokenizer_name "parler-tts/parler_tts_mini_v0.1" \
    --prompt_tokenizer_name "parler-tts/parler_tts_mini_v0.1" \
    --report_to "wandb" \
    --overwrite_output_dir true \
    --train_dataset_name "ylacombe/jenny-tts-6h" \
    --train_metadata_dataset_name "ylacombe/jenny-tts-6h-tagged" \
    --train_dataset_config_name "default" \
    --train_split_name "train" \
    --eval_dataset_name "ylacombe/jenny-tts-6h" \
    --eval_metadata_dataset_name "ylacombe/jenny-tts-6h-tagged" \
    --eval_dataset_config_name "default" \
    --eval_split_name "train" \
    --max_eval_samples 8 \
    --per_device_eval_batch_size 8 \
    --target_audio_column_name "audio" \
    --description_column_name "text_description" \
    --prompt_column_name "text" \
    --max_duration_in_seconds 20 \
    --min_duration_in_seconds 2.0 \
    --max_text_length 400 \
    --preprocessing_num_workers 2 \
    --do_train true \
    --num_train_epochs 2 \
    --gradient_accumulation_steps 18 \
    --gradient_checkpointing true \
    --per_device_train_batch_size 2 \
    --learning_rate 0.00008 \
    --adam_beta1 0.9 \
    --adam_beta2 0.99 \
    --weight_decay 0.01 \
    --lr_scheduler_type "constant_with_warmup" \
    --warmup_steps 50 \
    --logging_steps 2 \
    --freeze_text_encoder true \
    --audio_encoder_per_device_batch_size 4 \
    --dtype "float16" \
    --seed 456 \
    --output_dir "./output_dir_training/" \
    --temporary_save_to_disk "./audio_code_tmp/" \
    --save_to_disk "./tmp_dataset_audio/" \
    --dataloader_num_workers 2 \
    --do_eval \
    --predict_with_generate \
    --include_inputs_for_metrics \
    --group_by_length true
# Out:
# The following values were not passed to `accelerate launch` and had defaults used instead:
# 	`--num_processes` was set to a value of `1`
# 	`--num_machines` was set to a value of `1`
# 	`--mixed_precision` was set to a value of `'no'`
# 	`--dynamo_backend` was set to a value of `'no'`
# To avoid this warning pass in values for each of the problematic parameters or run `accelerate config`.
# 2025-03-12 05:55:35.343354: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1741758935.364011   12519 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1741758935.370625   12519 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-03-12 05:55:35.394356: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Flash attention 2 is not installed
# Using `include_inputs_for_metrics` is deprecated and will be removed in version 5 of 🤗 Transformers. Please use `include_for_metrics` list argument instead.
# wandb: (1) Create a W&B account
# wandb: (2) Use an existing W&B account
# wandb: (3) Don't visualize my results
# wandb: Enter your choice: 3
# wandb: You chose "Don't visualize my results"
# wandb: Tracking run with wandb version 0.16.6
# wandb: W&B syncing is set to `offline` in this directory.
# wandb: Run `wandb online` or set WANDB_MODE=online to enable cloud syncing.
# 03/12/2025 05:55:53 - WARNING - __main__ - Process rank: 0, device: cuda:0, n_gpu: 1, distributed training: False, 16-bits training: False
# 03/12/2025 05:55:53 - INFO - __main__ - Training/evaluation parameters ParlerTTSTrainingArguments(
# _n_gpu=1,
# accelerator_config={'split_batches': False, 'dispatch_batches': None, 'even_batches': True, 'use_seedable_sampler': True, 'non_blocking': False, 'gradient_accumulation_kwargs': None, 'use_configured_state': False},
# adafactor=False,
# adam_beta1=0.9,
# adam_beta2=0.99,
# adam_epsilon=1e-08,
# audio_encoder_per_device_batch_size=4,
# auto_find_batch_size=False,
# batch_eval_metrics=False,
# bf16=False,
# bf16_full_eval=False,
# codebook_weights=None,
# compute_clap_similarity_metric=True,
# compute_noise_level_metric=True,
# data_seed=None,
# dataloader_drop_last=False,
# dataloader_num_workers=2,
# dataloader_persistent_workers=False,
# dataloader_pin_memory=True,
# dataloader_prefetch_factor=None,
# ddp_backend=None,
# ddp_broadcast_buffers=None,
# ddp_bucket_cap_mb=None,
# ddp_find_unused_parameters=None,
# ddp_timeout=1800,
# debug=[],
# deepspeed=None,
# disable_tqdm=False,
# dispatch_batches=None,
# do_eval=True,
# do_predict=False,
# do_train=True,
# dtype=float16,
# eval_accumulation_steps=None,
# eval_dataloader_num_workers=0,
# eval_delay=0,
# eval_do_concat_batches=True,
# eval_generation_steps=None,
# eval_on_start=False,
# eval_steps=None,
# eval_strategy=IntervalStrategy.NO,
# eval_use_gather_object=False,
# evaluation_strategy=None,
# fp16=False,
# fp16_backend=auto,
# fp16_full_eval=False,
# fp16_opt_level=O1,
# fsdp=[],
# fsdp_config={'min_num_params': 0, 'xla': False, 'xla_fsdp_v2': False, 'xla_fsdp_grad_ckpt': False},
# fsdp_min_num_params=0,
# fsdp_transformer_layer_cls_to_wrap=None,
# full_determinism=False,
# generation_config=None,
# generation_max_length=None,
# generation_num_beams=None,
# gradient_accumulation_steps=18,
# gradient_checkpointing=True,
# gradient_checkpointing_kwargs=None,
# greater_is_better=None,
# group_by_length=True,
# half_precision_backend=auto,
# hub_always_push=False,
# hub_model_id=None,
# hub_private_repo=False,
# hub_strategy=HubStrategy.EVERY_SAVE,
# hub_token=<HUB_TOKEN>,
# ignore_data_skip=False,
# include_for_metrics=['inputs'],
# include_inputs_for_metrics=True,
# include_num_input_tokens_seen=False,
# include_tokens_per_second=False,
# jit_mode_eval=False,
# label_names=None,
# label_smoothing_factor=0.0,
# learning_rate=8e-05,
# length_column_name=length,
# load_best_model_at_end=False,
# local_rank=0,
# log_level=passive,
# log_level_replica=warning,
# log_on_each_node=True,
# logging_dir=./output_dir_training/runs/Mar12_05-55-41_bfd9ef44ef44,
# logging_first_step=False,
# logging_nan_inf_filter=True,
# logging_steps=2,
# logging_strategy=IntervalStrategy.STEPS,
# lr_scheduler_kwargs={},
# lr_scheduler_type=SchedulerType.CONSTANT_WITH_WARMUP,
# max_grad_norm=1.0,
# max_steps=-1,
# metric_for_best_model=None,
# mp_parameters=,
# neftune_noise_alpha=None,
# no_cuda=False,
# noise_level_to_compute_clean_wer=25,
# num_train_epochs=2.0,
# optim=OptimizerNames.ADAMW_TORCH,
# optim_args=None,
# optim_target_modules=None,
# output_dir=./output_dir_training/,
# overwrite_output_dir=True,
# past_index=-1,
# per_device_eval_batch_size=8,
# per_device_train_batch_size=2,
# predict_with_generate=True,
# prediction_loss_only=False,
# push_to_hub=False,
# push_to_hub_model_id=None,
# push_to_hub_organization=None,
# push_to_hub_token=<PUSH_TO_HUB_TOKEN>,
# ray_scope=last,
# remove_unused_columns=True,
# report_to=['wandb'],
# restore_callback_states_from_checkpoint=False,
# resume_from_checkpoint=None,
# run_name=./output_dir_training/,
# save_on_each_node=False,
# save_only_model=False,
# save_safetensors=True,
# save_steps=500,
# save_strategy=IntervalStrategy.STEPS,
# save_total_limit=None,
# seed=456,
# skip_memory_metrics=True,
# sortish_sampler=False,
# split_batches=None,
# tf32=None,
# torch_compile=False,
# torch_compile_backend=None,
# torch_compile_mode=None,
# torch_empty_cache_steps=None,
# torchdynamo=None,
# tpu_metrics_debug=False,
# tpu_num_cores=None,
# use_cpu=False,
# use_ipex=False,
# use_legacy_prediction_loop=False,
# use_liger_kernel=False,
# use_mps_device=False,
# warmup_ratio=0.0,
# warmup_steps=50,
# weight_decay=0.01,
# )
# loading configuration file preprocessor_config.json from cache at /root/.cache/huggingface/hub/models--parler-tts--dac_44khZ_8kbps/snapshots/db52bea859d9411e0beb44a3ea923a8731ee4197/preprocessor_config.json
# Feature extractor EncodecFeatureExtractor {
#   "chunk_length_s": null,
#   "feature_extractor_type": "EncodecFeatureExtractor",
#   "feature_size": 1,
#   "overlap": null,
#   "padding_side": "right",
#   "padding_value": 0.0,
#   "return_attention_mask": true,
#   "sampling_rate": 44100
# }
#
# loading file spiece.model from cache at /root/.cache/huggingface/hub/models--parler-tts--parler_tts_mini_v0.1/snapshots/e02fd18e77d38b49a85c7a9a85189a64b8472544/spiece.model
# loading file tokenizer.json from cache at /root/.cache/huggingface/hub/models--parler-tts--parler_tts_mini_v0.1/snapshots/e02fd18e77d38b49a85c7a9a85189a64b8472544/tokenizer.json
# loading file added_tokens.json from cache at None
# loading file special_tokens_map.json from cache at /root/.cache/huggingface/hub/models--parler-tts--parler_tts_mini_v0.1/snapshots/e02fd18e77d38b49a85c7a9a85189a64b8472544/special_tokens_map.json
# loading file tokenizer_config.json from cache at /root/.cache/huggingface/hub/models--parler-tts--parler_tts_mini_v0.1/snapshots/e02fd18e77d38b49a85c7a9a85189a64b8472544/tokenizer_config.json
# You set `add_prefix_space`. The tokenizer needs to be converted from the slow tokenizers
# loading file spiece.model from cache at /root/.cache/huggingface/hub/models--parler-tts--parler_tts_mini_v0.1/snapshots/e02fd18e77d38b49a85c7a9a85189a64b8472544/spiece.model
# loading file tokenizer.json from cache at /root/.cache/huggingface/hub/models--parler-tts--parler_tts_mini_v0.1/snapshots/e02fd18e77d38b49a85c7a9a85189a64b8472544/tokenizer.json
# loading file added_tokens.json from cache at None
# loading file special_tokens_map.json from cache at /root/.cache/huggingface/hub/models--parler-tts--parler_tts_mini_v0.1/snapshots/e02fd18e77d38b49a85c7a9a85189a64b8472544/special_tokens_map.json
# loading file tokenizer_config.json from cache at /root/.cache/huggingface/hub/models--parler-tts--parler_tts_mini_v0.1/snapshots/e02fd18e77d38b49a85c7a9a85189a64b8472544/tokenizer_config.json
# 03/12/2025 05:55:55 - WARNING - __main__ - Disabling fast tokenizer warning: https://github.com/huggingface/transformers/blob/main/src/transformers/tokenization_utils_base.py#L3231-L3235
# Combining datasets...:   0% 0/1 [00:00<?, ?it/s]03/12/2025 05:55:59 - INFO - __main__ - Merging ylacombe/jenny-tts-6h - train with ylacombe/jenny-tts-6h-tagged - train
# Combining datasets...: 100% 1/1 [00:07<00:00,  7.75s/it]
# Combining datasets...:   0% 0/1 [00:00<?, ?it/s]03/12/2025 05:56:05 - INFO - __main__ - Merging ylacombe/jenny-tts-6h - train with ylacombe/jenny-tts-6h-tagged - train
# Combining datasets...: 100% 1/1 [00:04<00:00,  4.05s/it]
# config.json: 100% 7.42k/7.42k [00:00<00:00, 19.3MB/s]
# loading configuration file config.json from cache at /root/.cache/huggingface/hub/models--parler-tts--parler_tts_mini_v0.1/snapshots/e02fd18e77d38b49a85c7a9a85189a64b8472544/config.json
# Model config ParlerTTSConfig {
#   "_name_or_path": "/fsx/yoach/tmp/artefacts/training-400M-punctuated-v2/",
#   "architectures": [
#     "ParlerTTSForConditionalGeneration"
#   ],
#   "audio_encoder": {
#     "_attn_implementation_autoset": false,
#     "_name_or_path": "ylacombe/dac_44khZ_8kbps",
#     "add_cross_attention": false,
#     "architectures": [
#       "DACModel"
#     ],
#     "bad_words_ids": null,
#     "begin_suppress_tokens": null,
#     "bos_token_id": null,
#     "chunk_size_feed_forward": 0,
#     "codebook_size": 1024,
#     "cross_attention_hidden_size": null,
#     "decoder_start_token_id": null,
#     "diversity_penalty": 0.0,
#     "do_sample": false,
#     "early_stopping": false,
#     "encoder_no_repeat_ngram_size": 0,
#     "eos_token_id": null,
#     "exponential_decay_length_penalty": null,
#     "finetuning_task": null,
#     "forced_bos_token_id": null,
#     "forced_eos_token_id": null,
#     "frame_rate": 86,
#     "id2label": {
#       "0": "LABEL_0",
#       "1": "LABEL_1"
#     },
#     "is_decoder": false,
#     "is_encoder_decoder": false,
#     "label2id": {
#       "LABEL_0": 0,
#       "LABEL_1": 1
#     },
#     "latent_dim": 1024,
#     "length_penalty": 1.0,
#     "max_length": 20,
#     "min_length": 0,
#     "model_bitrate": 8,
#     "model_type": "dac_on_the_hub",
#     "no_repeat_ngram_size": 0,
#     "num_beam_groups": 1,
#     "num_beams": 1,
#     "num_codebooks": 9,
#     "num_return_sequences": 1,
#     "output_attentions": false,
#     "output_hidden_states": false,
#     "output_scores": false,
#     "pad_token_id": null,
#     "prefix": null,
#     "problem_type": null,
#     "pruned_heads": {},
#     "remove_invalid_values": false,
#     "repetition_penalty": 1.0,
#     "return_dict": true,
#     "return_dict_in_generate": false,
#     "sampling_rate": 44100,
#     "sep_token_id": null,
#     "suppress_tokens": null,
#     "task_specific_params": null,
#     "temperature": 1.0,
#     "tf_legacy_loss": false,
#     "tie_encoder_decoder": false,
#     "tie_word_embeddings": true,
#     "tokenizer_class": null,
#     "top_k": 50,
#     "top_p": 1.0,
#     "torch_dtype": "float32",
#     "torchscript": false,
#     "typical_p": 1.0,
#     "use_bfloat16": false
#   },
#   "decoder": {
#     "_attn_implementation_autoset": false,
#     "_name_or_path": "/fsx/yoach/tmp/artefacts/decoder_400M/",
#     "activation_dropout": 0.0,
#     "activation_function": "gelu",
#     "add_cross_attention": true,
#     "architectures": [
#       "ParlerTTSForCausalLM"
#     ],
#     "attention_dropout": 0.0,
#     "bad_words_ids": null,
#     "begin_suppress_tokens": null,
#     "bos_token_id": 1025,
#     "chunk_size_feed_forward": 0,
#     "codebook_weights": null,
#     "cross_attention_hidden_size": null,
#     "cross_attention_implementation_strategy": null,
#     "decoder_start_token_id": null,
#     "diversity_penalty": 0.0,
#     "do_sample": false,
#     "dropout": 0.1,
#     "early_stopping": false,
#     "encoder_no_repeat_ngram_size": 0,
#     "eos_token_id": 1024,
#     "exponential_decay_length_penalty": null,
#     "ffn_dim": 4096,
#     "finetuning_task": null,
#     "forced_bos_token_id": null,
#     "forced_eos_token_id": null,
#     "hidden_size": 1024,
#     "id2label": {
#       "0": "LABEL_0",
#       "1": "LABEL_1"
#     },
#     "initializer_factor": 0.02,
#     "is_decoder": true,
#     "is_encoder_decoder": false,
#     "label2id": {
#       "LABEL_0": 0,
#       "LABEL_1": 1
#     },
#     "layerdrop": 0.0,
#     "length_penalty": 1.0,
#     "max_length": 20,
#     "max_position_embeddings": 4096,
#     "min_length": 0,
#     "model_type": "parler_tts_decoder",
#     "no_repeat_ngram_size": 0,
#     "num_attention_heads": 16,
#     "num_beam_groups": 1,
#     "num_beams": 1,
#     "num_codebooks": 9,
#     "num_cross_attention_key_value_heads": 16,
#     "num_hidden_layers": 24,
#     "num_key_value_heads": 16,
#     "num_return_sequences": 1,
#     "output_attentions": false,
#     "output_hidden_states": false,
#     "output_scores": false,
#     "pad_token_id": 1024,
#     "prefix": null,
#     "problem_type": null,
#     "pruned_heads": {},
#     "remove_invalid_values": false,
#     "repetition_penalty": 1.0,
#     "return_dict": true,
#     "return_dict_in_generate": false,
#     "rope_embeddings": false,
#     "rope_theta": 10000.0,
#     "scale_embedding": false,
#     "sep_token_id": null,
#     "suppress_tokens": null,
#     "task_specific_params": null,
#     "temperature": 1.0,
#     "tf_legacy_loss": false,
#     "tie_encoder_decoder": false,
#     "tie_word_embeddings": false,
#     "tokenizer_class": null,
#     "top_k": 50,
#     "top_p": 1.0,
#     "torch_dtype": "float32",
#     "torchscript": false,
#     "typical_p": 1.0,
#     "use_bfloat16": false,
#     "use_cache": true,
#     "use_fused_lm_heads": false,
#     "vocab_size": 1088
#   },
#   "decoder_start_token_id": 1025,
#   "is_encoder_decoder": true,
#   "model_type": "parler_tts",
#   "pad_token_id": 1024,
#   "prompt_cross_attention": false,
#   "text_encoder": {
#     "_attn_implementation_autoset": false,
#     "_name_or_path": "google/flan-t5-base",
#     "add_cross_attention": false,
#     "architectures": [
#       "T5ForConditionalGeneration"
#     ],
#     "bad_words_ids": null,
#     "begin_suppress_tokens": null,
#     "bos_token_id": null,
#     "chunk_size_feed_forward": 0,
#     "classifier_dropout": 0.0,
#     "cross_attention_hidden_size": null,
#     "d_ff": 2048,
#     "d_kv": 64,
#     "d_model": 768,
#     "decoder_start_token_id": 0,
#     "dense_act_fn": "gelu_new",
#     "diversity_penalty": 0.0,
#     "do_sample": false,
#     "dropout_rate": 0.1,
#     "early_stopping": false,
#     "encoder_no_repeat_ngram_size": 0,
#     "eos_token_id": 1,
#     "exponential_decay_length_penalty": null,
#     "feed_forward_proj": "gated-gelu",
#     "finetuning_task": null,
#     "forced_bos_token_id": null,
#     "forced_eos_token_id": null,
#     "id2label": {
#       "0": "LABEL_0",
#       "1": "LABEL_1"
#     },
#     "initializer_factor": 1.0,
#     "is_decoder": false,
#     "is_encoder_decoder": true,
#     "is_gated_act": true,
#     "label2id": {
#       "LABEL_0": 0,
#       "LABEL_1": 1
#     },
#     "layer_norm_epsilon": 1e-06,
#     "length_penalty": 1.0,
#     "max_length": 20,
#     "min_length": 0,
#     "model_type": "t5",
#     "n_positions": 512,
#     "no_repeat_ngram_size": 0,
#     "num_beam_groups": 1,
#     "num_beams": 1,
#     "num_decoder_layers": 12,
#     "num_heads": 12,
#     "num_layers": 12,
#     "num_return_sequences": 1,
#     "output_attentions": false,
#     "output_hidden_states": false,
#     "output_past": true,
#     "output_scores": false,
#     "pad_token_id": 0,
#     "prefix": null,
#     "problem_type": null,
#     "pruned_heads": {},
#     "relative_attention_max_distance": 128,
#     "relative_attention_num_buckets": 32,
#     "remove_invalid_values": false,
#     "repetition_penalty": 1.0,
#     "return_dict": true,
#     "return_dict_in_generate": false,
#     "sep_token_id": null,
#     "suppress_tokens": null,
#     "task_specific_params": {
#       "summarization": {
#         "early_stopping": true,
#         "length_penalty": 2.0,
#         "max_length": 200,
#         "min_length": 30,
#         "no_repeat_ngram_size": 3,
#         "num_beams": 4,
#         "prefix": "summarize: "
#       },
#       "translation_en_to_de": {
#         "early_stopping": true,
#         "max_length": 300,
#         "num_beams": 4,
#         "prefix": "translate English to German: "
#       },
#       "translation_en_to_fr": {
#         "early_stopping": true,
#         "max_length": 300,
#         "num_beams": 4,
#         "prefix": "translate English to French: "
#       },
#       "translation_en_to_ro": {
#         "early_stopping": true,
#         "max_length": 300,
#         "num_beams": 4,
#         "prefix": "translate English to Romanian: "
#       }
#     },
#     "temperature": 1.0,
#     "tf_legacy_loss": false,
#     "tie_encoder_decoder": false,
#     "tie_word_embeddings": false,
#     "tokenizer_class": null,
#     "top_k": 50,
#     "top_p": 1.0,
#     "torch_dtype": null,
#     "torchscript": false,
#     "typical_p": 1.0,
#     "use_bfloat16": false,
#     "use_cache": true,
#     "vocab_size": 32128
#   },
#   "torch_dtype": "float32",
#   "transformers_version": "4.46.1",
#   "vocab_size": 32128
# }
#
# model.safetensors: 100% 2.59G/2.59G [01:44<00:00, 24.7MB/s]
# loading weights file model.safetensors from cache at /root/.cache/huggingface/hub/models--parler-tts--parler_tts_mini_v0.1/snapshots/e02fd18e77d38b49a85c7a9a85189a64b8472544/model.safetensors
# Generate config GenerationConfig {
#   "decoder_start_token_id": 1025,
#   "pad_token_id": 1024
# }
#
# Instantiating T5EncoderModel model under default dtype torch.float32.
# Instantiating DACModel model under default dtype torch.float32.
# /usr/local/lib/python3.11/dist-packages/torch/nn/utils/weight_norm.py:143: FutureWarning: `torch.nn.utils.weight_norm` is deprecated in favor of `torch.nn.utils.parametrizations.weight_norm`.
#   WeightNorm.apply(module, name, dim)
# Instantiating ParlerTTSForCausalLM model under default dtype torch.float32.
# Generate config GenerationConfig {
#   "bos_token_id": 1025,
#   "eos_token_id": 1024,
#   "pad_token_id": 1024
# }
#
# 03/12/2025 05:58:04 - WARNING - parler_tts.modeling_parler_tts - Config of the text_encoder: <class 'transformers.models.t5.modeling_t5.T5EncoderModel'> is overwritten by shared text_encoder config: T5Config {
#   "_name_or_path": "google/flan-t5-base",
#   "architectures": [
#     "T5ForConditionalGeneration"
#   ],
#   "classifier_dropout": 0.0,
#   "d_ff": 2048,
#   "d_kv": 64,
#   "d_model": 768,
#   "decoder_start_token_id": 0,
#   "dense_act_fn": "gelu_new",
#   "dropout_rate": 0.1,
#   "eos_token_id": 1,
#   "feed_forward_proj": "gated-gelu",
#   "initializer_factor": 1.0,
#   "is_encoder_decoder": true,
#   "is_gated_act": true,
#   "layer_norm_epsilon": 1e-06,
#   "model_type": "t5",
#   "n_positions": 512,
#   "num_decoder_layers": 12,
#   "num_heads": 12,
#   "num_layers": 12,
#   "output_past": true,
#   "pad_token_id": 0,
#   "relative_attention_max_distance": 128,
#   "relative_attention_num_buckets": 32,
#   "task_specific_params": {
#     "summarization": {
#       "early_stopping": true,
#       "length_penalty": 2.0,
#       "max_length": 200,
#       "min_length": 30,
#       "no_repeat_ngram_size": 3,
#       "num_beams": 4,
#       "prefix": "summarize: "
#     },
#     "translation_en_to_de": {
#       "early_stopping": true,
#       "max_length": 300,
#       "num_beams": 4,
#       "prefix": "translate English to German: "
#     },
#     "translation_en_to_fr": {
#       "early_stopping": true,
#       "max_length": 300,
#       "num_beams": 4,
#       "prefix": "translate English to French: "
#     },
#     "translation_en_to_ro": {
#       "early_stopping": true,
#       "max_length": 300,
#       "num_beams": 4,
#       "prefix": "translate English to Romanian: "
#     }
#   },
#   "tie_word_embeddings": false,
#   "transformers_version": "4.46.1",
#   "use_cache": true,
#   "vocab_size": 32128
# }
#
# 03/12/2025 05:58:04 - WARNING - parler_tts.modeling_parler_tts - Config of the audio_encoder: <class 'parler_tts.dac_wrapper.modeling_dac.DACModel'> is overwritten by shared audio_encoder config: DACConfig {
#   "_name_or_path": "ylacombe/dac_44khZ_8kbps",
#   "architectures": [
#     "DACModel"
#   ],
#   "codebook_size": 1024,
#   "frame_rate": 86,
#   "latent_dim": 1024,
#   "model_bitrate": 8,
#   "model_type": "dac_on_the_hub",
#   "num_codebooks": 9,
#   "sampling_rate": 44100,
#   "torch_dtype": "float32",
#   "transformers_version": "4.46.1"
# }
#
# 03/12/2025 05:58:04 - WARNING - parler_tts.modeling_parler_tts - Config of the decoder: <class 'parler_tts.modeling_parler_tts.ParlerTTSForCausalLM'> is overwritten by shared decoder config: ParlerTTSDecoderConfig {
#   "_name_or_path": "/fsx/yoach/tmp/artefacts/decoder_400M/",
#   "activation_dropout": 0.0,
#   "activation_function": "gelu",
#   "add_cross_attention": true,
#   "architectures": [
#     "ParlerTTSForCausalLM"
#   ],
#   "attention_dropout": 0.0,
#   "bos_token_id": 1025,
#   "codebook_weights": null,
#   "cross_attention_implementation_strategy": null,
#   "dropout": 0.1,
#   "eos_token_id": 1024,
#   "ffn_dim": 4096,
#   "hidden_size": 1024,
#   "initializer_factor": 0.02,
#   "is_decoder": true,
#   "layerdrop": 0.0,
#   "max_position_embeddings": 4096,
#   "model_type": "parler_tts_decoder",
#   "num_attention_heads": 16,
#   "num_codebooks": 9,
#   "num_cross_attention_key_value_heads": 16,
#   "num_hidden_layers": 24,
#   "num_key_value_heads": 16,
#   "pad_token_id": 1024,
#   "rope_embeddings": false,
#   "rope_theta": 10000.0,
#   "scale_embedding": false,
#   "tie_word_embeddings": false,
#   "torch_dtype": "float32",
#   "transformers_version": "4.46.1",
#   "use_cache": true,
#   "use_fused_lm_heads": false,
#   "vocab_size": 1088
# }
#
# All model checkpoint weights were used when initializing ParlerTTSForConditionalGeneration.
#
# All the weights of ParlerTTSForConditionalGeneration were initialized from the model checkpoint at parler-tts/parler_tts_mini_v0.1.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use ParlerTTSForConditionalGeneration for predictions without further training.
# generation_config.json: 100% 267/267 [00:00<00:00, 913kB/s]
# loading configuration file generation_config.json from cache at /root/.cache/huggingface/hub/models--parler-tts--parler_tts_mini_v0.1/snapshots/e02fd18e77d38b49a85c7a9a85189a64b8472544/generation_config.json
# Generate config GenerationConfig {
#   "bos_token_id": 1025,
#   "decoder_start_token_id": 1025,
#   "do_sample": true,
#   "eos_token_id": 1024,
#   "guidance_scale": 1.0,
#   "max_length": 2580,
#   "min_new_tokens": 50,
#   "pad_token_id": 1024
# }
#
# gathered_tensor tensor([0], device='cuda:0')
# Filter (num_proc=2): 100% 4000/4000 [00:00<00:00, 17811.59 examples/s]
# Filter (num_proc=2): 100% 8/8 [00:00<00:00, 43.57 examples/s]
# preprocess datasets (num_proc=2): 100% 4000/4000 [00:02<00:00, 1427.99 examples/s]
# preprocess datasets (num_proc=2): 100% 8/8 [00:00<00:00, 12.78 examples/s]
# 03/12/2025 05:58:11 - INFO - __main__ - *** Encode target audio with encodec ***
#  50% 499/1000 [07:08<06:54,  1.21it/s]
# Postprocessing labeling (num_proc=2):   0% 0/2000 [00:00<?, ? examples/s]
# Postprocessing labeling (num_proc=2):   0% 6/2000 [00:00<02:16, 14.62 examples/s]
# Postprocessing labeling (num_proc=2):   1% 19/2000 [00:00<00:46, 42.43 examples/s]
# Postprocessing labeling (num_proc=2):   2% 43/2000 [00:00<00:21, 92.57 examples/s]
# Postprocessing labeling (num_proc=2):   4% 80/2000 [00:00<00:11, 163.99 examples/s]
# Postprocessing labeling (num_proc=2):   5% 109/2000 [00:00<00:09, 196.79 examples/s]
# Postprocessing labeling (num_proc=2):   7% 148/2000 [00:00<00:07, 247.90 examples/s]
# Postprocessing labeling (num_proc=2):   9% 183/2000 [00:01<00:06, 266.61 examples/s]
# Postprocessing labeling (num_proc=2):  11% 213/2000 [00:01<00:06, 266.81 examples/s]
# Postprocessing labeling (num_proc=2):  12% 250/2000 [00:01<00:05, 292.99 examples/s]
# Postprocessing labeling (num_proc=2):  14% 285/2000 [00:01<00:05, 300.52 examples/s]
# Postprocessing labeling (num_proc=2):  16% 327/2000 [00:01<00:05, 329.09 examples/s]
# Postprocessing labeling (num_proc=2):  18% 364/2000 [00:01<00:05, 322.76 examples/s]
# Postprocessing labeling (num_proc=2):  20% 398/2000 [00:01<00:05, 316.00 examples/s]
# Postprocessing labeling (num_proc=2):  22% 436/2000 [00:01<00:04, 325.58 examples/s]
# Postprocessing labeling (num_proc=2):  24% 474/2000 [00:01<00:05, 304.83 examples/s]
# Postprocessing labeling (num_proc=2):  26% 512/2000 [00:02<00:04, 305.12 examples/s]
# Postprocessing labeling (num_proc=2):  27% 548/2000 [00:02<00:05, 288.12 examples/s]
# Postprocessing labeling (num_proc=2):  29% 587/2000 [00:02<00:04, 287.91 examples/s]
# Postprocessing labeling (num_proc=2):  31% 626/2000 [00:02<00:04, 309.25 examples/s]
# Postprocessing labeling (num_proc=2):  33% 658/2000 [00:02<00:04, 309.11 examples/s]
# Postprocessing labeling (num_proc=2):  35% 692/2000 [00:02<00:04, 274.16 examples/s]
# Postprocessing labeling (num_proc=2):  36% 721/2000 [00:02<00:04, 259.43 examples/s]
# Postprocessing labeling (num_proc=2):  38% 750/2000 [00:03<00:05, 240.11 examples/s]
# Postprocessing labeling (num_proc=2):  39% 775/2000 [00:03<00:05, 223.29 examples/s]
# Postprocessing labeling (num_proc=2):  40% 798/2000 [00:03<00:06, 197.70 examples/s]
# Postprocessing labeling (num_proc=2):  41% 821/2000 [00:03<00:05, 199.22 examples/s]
# Postprocessing labeling (num_proc=2):  42% 843/2000 [00:03<00:06, 191.82 examples/s]
# Postprocessing labeling (num_proc=2):  43% 864/2000 [00:03<00:05, 190.46 examples/s]
# Postprocessing labeling (num_proc=2):  44% 885/2000 [00:03<00:05, 188.26 examples/s]
# Postprocessing labeling (num_proc=2):  45% 909/2000 [00:03<00:06, 170.12 examples/s]
# Postprocessing labeling (num_proc=2):  46% 927/2000 [00:04<00:06, 167.94 examples/s]
# Postprocessing labeling (num_proc=2):  47% 948/2000 [00:04<00:06, 162.72 examples/s]
# Postprocessing labeling (num_proc=2):  48% 966/2000 [00:04<00:06, 160.54 examples/s]
# Postprocessing labeling (num_proc=2):  50% 990/2000 [00:04<00:05, 175.04 examples/s]
# Postprocessing labeling (num_proc=2):  51% 1013/2000 [00:04<00:05, 186.22 examples/s]
# Postprocessing labeling (num_proc=2):  52% 1032/2000 [00:04<00:05, 179.48 examples/s]
# Postprocessing labeling (num_proc=2):  53% 1054/2000 [00:04<00:05, 188.06 examples/s]
# Postprocessing labeling (num_proc=2):  54% 1076/2000 [00:04<00:05, 167.97 examples/s]
# Postprocessing labeling (num_proc=2):  55% 1095/2000 [00:05<00:05, 162.36 examples/s]
# Postprocessing labeling (num_proc=2):  56% 1116/2000 [00:05<00:05, 162.04 examples/s]
# Postprocessing labeling (num_proc=2):  57% 1145/2000 [00:05<00:04, 189.55 examples/s]
# Postprocessing labeling (num_proc=2):  58% 1169/2000 [00:05<00:04, 194.10 examples/s]
# Postprocessing labeling (num_proc=2):  59% 1189/2000 [00:05<00:04, 193.40 examples/s]
# Postprocessing labeling (num_proc=2):  61% 1214/2000 [00:05<00:03, 199.54 examples/s]
# Postprocessing labeling (num_proc=2):  63% 1256/2000 [00:05<00:02, 254.95 examples/s]
# Postprocessing labeling (num_proc=2):  65% 1294/2000 [00:05<00:02, 280.52 examples/s]
# Postprocessing labeling (num_proc=2):  67% 1331/2000 [00:05<00:02, 296.94 examples/s]
# Postprocessing labeling (num_proc=2):  68% 1364/2000 [00:06<00:02, 295.34 examples/s]
# Postprocessing labeling (num_proc=2):  70% 1396/2000 [00:06<00:02, 295.51 examples/s]
# Postprocessing labeling (num_proc=2):  72% 1430/2000 [00:06<00:01, 303.94 examples/s]
# Postprocessing labeling (num_proc=2):  73% 1464/2000 [00:06<00:01, 308.82 examples/s]
# Postprocessing labeling (num_proc=2):  75% 1503/2000 [00:06<00:01, 307.12 examples/s]
# Postprocessing labeling (num_proc=2):  77% 1536/2000 [00:06<00:01, 284.15 examples/s]
# Postprocessing labeling (num_proc=2):  78% 1568/2000 [00:06<00:01, 287.68 examples/s]
# Postprocessing labeling (num_proc=2):  80% 1600/2000 [00:06<00:01, 273.27 examples/s]
# Postprocessing labeling (num_proc=2):  82% 1630/2000 [00:07<00:01, 268.26 examples/s]
# Postprocessing labeling (num_proc=2):  83% 1661/2000 [00:07<00:01, 274.31 examples/s]
# Postprocessing labeling (num_proc=2):  85% 1697/2000 [00:07<00:01, 290.56 examples/s]
# Postprocessing labeling (num_proc=2):  86% 1730/2000 [00:07<00:00, 291.29 examples/s]
# Postprocessing labeling (num_proc=2):  88% 1765/2000 [00:07<00:00, 278.80 examples/s]
# Postprocessing labeling (num_proc=2):  90% 1797/2000 [00:07<00:00, 287.38 examples/s]
# Postprocessing labeling (num_proc=2):  91% 1827/2000 [00:07<00:00, 285.94 examples/s]
# Postprocessing labeling (num_proc=2):  93% 1857/2000 [00:07<00:00, 242.72 examples/s]
# Postprocessing labeling (num_proc=2):  94% 1889/2000 [00:08<00:00, 199.36 examples/s]
# Postprocessing labeling (num_proc=2):  96% 1919/2000 [00:08<00:00, 167.04 examples/s]
# Postprocessing labeling (num_proc=2):  98% 1953/2000 [00:08<00:00, 191.53 examples/s]
# Postprocessing labeling (num_proc=2): 100% 2000/2000 [00:09<00:00, 217.26 examples/s]
#
# Saving the dataset (0/1 shards):   0% 0/2000 [00:00<?, ? examples/s]
# Saving the dataset (1/1 shards): 100% 2000/2000 [00:00<00:00, 94304.88 examples/s]
# 100% 999/1000 [14:19<00:00,  1.33it/s]
# Postprocessing labeling (num_proc=2):   0% 0/2000 [00:00<?, ? examples/s]
# Postprocessing labeling (num_proc=2):   0% 7/2000 [00:00<02:02, 16.24 examples/s]
# Postprocessing labeling (num_proc=2):   1% 21/2000 [00:00<00:42, 46.67 examples/s]
# Postprocessing labeling (num_proc=2):   2% 34/2000 [00:00<00:29, 66.89 examples/s]
# Postprocessing labeling (num_proc=2):   3% 56/2000 [00:00<00:18, 106.52 examples/s]
# Postprocessing labeling (num_proc=2):   4% 89/2000 [00:00<00:11, 164.62 examples/s]
# Postprocessing labeling (num_proc=2):   6% 116/2000 [00:00<00:09, 192.08 examples/s]
# Postprocessing labeling (num_proc=2):   8% 151/2000 [00:01<00:07, 233.89 examples/s]
# Postprocessing labeling (num_proc=2):   9% 188/2000 [00:01<00:06, 265.09 examples/s]
# Postprocessing labeling (num_proc=2):  11% 221/2000 [00:01<00:06, 277.61 examples/s]
# Postprocessing labeling (num_proc=2):  13% 262/2000 [00:01<00:05, 310.65 examples/s]
# Postprocessing labeling (num_proc=2):  15% 298/2000 [00:01<00:05, 318.14 examples/s]
# Postprocessing labeling (num_proc=2):  17% 344/2000 [00:01<00:04, 337.88 examples/s]
# Postprocessing labeling (num_proc=2):  19% 386/2000 [00:01<00:05, 311.72 examples/s]
# Postprocessing labeling (num_proc=2):  21% 418/2000 [00:01<00:05, 310.28 examples/s]
# Postprocessing labeling (num_proc=2):  23% 451/2000 [00:01<00:05, 309.72 examples/s]
# Postprocessing labeling (num_proc=2):  24% 490/2000 [00:02<00:04, 330.60 examples/s]
# Postprocessing labeling (num_proc=2):  26% 527/2000 [00:02<00:04, 336.97 examples/s]
# Postprocessing labeling (num_proc=2):  29% 572/2000 [00:02<00:04, 339.07 examples/s]
# Postprocessing labeling (num_proc=2):  31% 613/2000 [00:02<00:04, 321.26 examples/s]
# Postprocessing labeling (num_proc=2):  32% 650/2000 [00:02<00:04, 322.90 examples/s]
# Postprocessing labeling (num_proc=2):  34% 685/2000 [00:02<00:04, 325.24 examples/s]
# Postprocessing labeling (num_proc=2):  36% 723/2000 [00:02<00:03, 335.06 examples/s]
# Postprocessing labeling (num_proc=2):  38% 758/2000 [00:02<00:03, 336.23 examples/s]
# Postprocessing labeling (num_proc=2):  40% 793/2000 [00:02<00:03, 332.84 examples/s]
# Postprocessing labeling (num_proc=2):  41% 828/2000 [00:03<00:03, 327.61 examples/s]
# Postprocessing labeling (num_proc=2):  43% 867/2000 [00:03<00:03, 336.05 examples/s]
# Postprocessing labeling (num_proc=2):  45% 905/2000 [00:03<00:03, 337.86 examples/s]
# Postprocessing labeling (num_proc=2):  47% 949/2000 [00:03<00:03, 324.97 examples/s]
# Postprocessing labeling (num_proc=2):  49% 987/2000 [00:03<00:03, 333.97 examples/s]
# Postprocessing labeling (num_proc=2):  51% 1024/2000 [00:03<00:02, 339.44 examples/s]
# Postprocessing labeling (num_proc=2):  53% 1060/2000 [00:03<00:02, 340.82 examples/s]
# Postprocessing labeling (num_proc=2):  55% 1099/2000 [00:03<00:02, 320.73 examples/s]
# Postprocessing labeling (num_proc=2):  57% 1139/2000 [00:04<00:02, 337.74 examples/s]
# Postprocessing labeling (num_proc=2):  59% 1182/2000 [00:04<00:02, 331.91 examples/s]
# Postprocessing labeling (num_proc=2):  61% 1219/2000 [00:04<00:02, 330.58 examples/s]
# Postprocessing labeling (num_proc=2):  63% 1253/2000 [00:04<00:02, 305.73 examples/s]
# Postprocessing labeling (num_proc=2):  64% 1284/2000 [00:04<00:02, 296.16 examples/s]
# Postprocessing labeling (num_proc=2):  66% 1314/2000 [00:04<00:02, 293.65 examples/s]
# Postprocessing labeling (num_proc=2):  67% 1346/2000 [00:04<00:02, 291.84 examples/s]
# Postprocessing labeling (num_proc=2):  69% 1380/2000 [00:04<00:02, 288.01 examples/s]
# Postprocessing labeling (num_proc=2):  70% 1410/2000 [00:04<00:02, 285.70 examples/s]
# Postprocessing labeling (num_proc=2):  72% 1442/2000 [00:05<00:01, 285.94 examples/s]
# Postprocessing labeling (num_proc=2):  74% 1474/2000 [00:05<00:01, 285.98 examples/s]
# Postprocessing labeling (num_proc=2):  75% 1507/2000 [00:05<00:01, 292.29 examples/s]
# Postprocessing labeling (num_proc=2):  77% 1540/2000 [00:05<00:01, 297.35 examples/s]
# Postprocessing labeling (num_proc=2):  79% 1575/2000 [00:05<00:01, 302.10 examples/s]
# Postprocessing labeling (num_proc=2):  81% 1612/2000 [00:05<00:01, 316.56 examples/s]
# Postprocessing labeling (num_proc=2):  82% 1647/2000 [00:05<00:01, 316.73 examples/s]
# Postprocessing labeling (num_proc=2):  84% 1686/2000 [00:05<00:01, 310.60 examples/s]
# Postprocessing labeling (num_proc=2):  86% 1720/2000 [00:05<00:00, 314.46 examples/s]
# Postprocessing labeling (num_proc=2):  88% 1756/2000 [00:06<00:00, 323.26 examples/s]
# Postprocessing labeling (num_proc=2):  90% 1790/2000 [00:06<00:00, 315.69 examples/s]
# Postprocessing labeling (num_proc=2):  91% 1823/2000 [00:06<00:00, 312.10 examples/s]
# Postprocessing labeling (num_proc=2):  93% 1859/2000 [00:06<00:00, 224.91 examples/s]
# Postprocessing labeling (num_proc=2):  94% 1889/2000 [00:06<00:00, 209.72 examples/s]
# Postprocessing labeling (num_proc=2):  96% 1917/2000 [00:06<00:00, 179.99 examples/s]
# Postprocessing labeling (num_proc=2):  97% 1943/2000 [00:07<00:00, 192.33 examples/s]
# Postprocessing labeling (num_proc=2):  98% 1968/2000 [00:07<00:00, 202.27 examples/s]
# Postprocessing labeling (num_proc=2): 100% 2000/2000 [00:07<00:00, 252.88 examples/s]
#
# Saving the dataset (0/1 shards):   0% 0/2000 [00:00<?, ? examples/s]
# Saving the dataset (1/1 shards): 100% 2000/2000 [00:00<00:00, 96076.23 examples/s]
# 100% 1000/1000 [14:28<00:00,  1.15it/s]
# 03/12/2025 06:12:39 - INFO - __main__ - Concatenating train: Dataset({
#     features: ['labels', 'target_length'],
#     num_rows: 4000
# }) with Dataset({
#     features: ['input_ids', 'prompt_input_ids'],
#     num_rows: 4000
# })
#  50% 1/2 [00:03<00:03,  3.44s/it]
# Postprocessing labeling (num_proc=2):   0% 0/8 [00:00<?, ? examples/s]
# Postprocessing labeling (num_proc=2): 100% 8/8 [00:00<00:00, 33.23 examples/s]
#
# Saving the dataset (0/1 shards):   0% 0/8 [00:00<?, ? examples/s]
# Saving the dataset (1/1 shards): 100% 8/8 [00:00<00:00, 1784.72 examples/s]
# 100% 2/2 [00:04<00:00,  2.36s/it]
# 03/12/2025 06:12:44 - INFO - __main__ - Concatenating eval: Dataset({
#     features: ['labels', 'target_length'],
#     num_rows: 8
# }) with Dataset({
#     features: ['input_ids', 'prompt_input_ids'],
#     num_rows: 8
# })
# Filter (num_proc=2): 100% 4000/4000 [00:00<00:00, 21176.59 examples/s]
# Filter (num_proc=2): 100% 8/8 [00:00<00:00, 44.70 examples/s]
# Saving the dataset (2/2 shards): 100% 3578/3578 [00:00<00:00, 9657.30 examples/s]
# Saving the dataset (2/2 shards): 100% 8/8 [00:00<00:00, 33.72 examples/s]
# 03/12/2025 06:12:46 - INFO - __main__ - Dataset saved at ./tmp_dataset_audio/
# Map (num_proc=2): 100% 3578/3578 [00:00<00:00, 4169.40 examples/s]
# Map (num_proc=2): 100% 8/8 [00:00<00:00, 43.39 examples/s]
# 03/12/2025 06:12:47 - INFO - __main__ - eval_steps is not set, evaluating at the end of each epoch
# 03/12/2025 06:12:58 - INFO - __main__ - ***** Running training *****
# 03/12/2025 06:12:58 - INFO - __main__ -   Num examples = 7128
# 03/12/2025 06:12:58 - INFO - __main__ -   Instantaneous batch size per device = 2
# 03/12/2025 06:12:58 - INFO - __main__ -   Gradient accumulation steps = 18
# 03/12/2025 06:12:58 - INFO - __main__ -   Total train batch size (w. parallel & distributed) = 36
# 03/12/2025 06:12:58 - INFO - __main__ -   Total optimization steps = 198
# Train steps ... :   0% 0/198 [00:00<?, ?it/s]tokenizer config file saved in ./output_dir_training/tokenizer_config.json
# Special tokens file saved in ./output_dir_training/special_tokens_map.json
# Copy vocab file to ./output_dir_training/spiece.model
# Feature extractor saved in ./output_dir_training/preprocessor_config.json
# Configuration saved in ./output_dir_training/config.json
# /usr/local/lib/python3.11/dist-packages/torch/utils/checkpoint.py:87: UserWarning: None of the inputs have requires_grad=True. Gradients will be None
#   warnings.warn(
# 03/12/2025 06:12:58 - WARNING - parler_tts.modeling_parler_tts - Passing a tuple of `past_key_values` is deprecated and will be removed in Transformers v4.43.0. You should pass an instance of `EncoderDecoderCache` instead, e.g. `past_key_values=EncoderDecoderCache.from_legacy_cache(past_key_values)`.
# 03/12/2025 06:12:58 - WARNING - parler_tts.modeling_parler_tts - `prompt_attention_mask` is specified but `attention_mask` is not. A full `attention_mask` will be created. Make sure this is the intended behaviour.
# 03/12/2025 06:12:58 - WARNING - parler_tts.modeling_parler_tts - `use_cache=True` is incompatible with gradient checkpointing`. Setting `use_cache=False`...
# Step... (2 / 198 | Loss: 4.437342166900635, Learning Rate: 3.2000000000000003e-06)
# Step... (4 / 198 | Loss: 4.988844394683838, Learning Rate: 6.4000000000000006e-06)
# Step... (6 / 198 | Loss: 8.921067237854004, Learning Rate: 9.600000000000001e-06)
# Step... (8 / 198 | Loss: 3.936115026473999, Learning Rate: 1.2800000000000001e-05)
# Step... (10 / 198 | Loss: 4.351994037628174, Learning Rate: 1.6000000000000003e-05)
# Step... (12 / 198 | Loss: 4.196243762969971, Learning Rate: 1.9200000000000003e-05)
# Step... (14 / 198 | Loss: 14.319025993347168, Learning Rate: 2.2400000000000002e-05)
# Step... (16 / 198 | Loss: 4.0416364669799805, Learning Rate: 2.5600000000000002e-05)
# Step... (18 / 198 | Loss: 3.9816370010375977, Learning Rate: 2.8800000000000002e-05)
# Step... (20 / 198 | Loss: 6.303067207336426, Learning Rate: 3.2000000000000005e-05)
# Step... (22 / 198 | Loss: 3.5391650199890137, Learning Rate: 3.52e-05)
# Step... (24 / 198 | Loss: 3.5918819904327393, Learning Rate: 3.8400000000000005e-05)
# Step... (26 / 198 | Loss: 3.764127492904663, Learning Rate: 4.16e-05)
# Step... (28 / 198 | Loss: 9.077942848205566, Learning Rate: 4.4800000000000005e-05)
# Step... (30 / 198 | Loss: 3.409130096435547, Learning Rate: 4.8e-05)
# Step... (32 / 198 | Loss: 3.982638120651245, Learning Rate: 5.1200000000000004e-05)
# Step... (34 / 198 | Loss: 5.30580472946167, Learning Rate: 5.440000000000001e-05)
# Step... (36 / 198 | Loss: 2.491098165512085, Learning Rate: 5.7600000000000004e-05)
# Step... (38 / 198 | Loss: 3.5911147594451904, Learning Rate: 6.080000000000001e-05)
# Step... (40 / 198 | Loss: 3.546396255493164, Learning Rate: 6.400000000000001e-05)
# Step... (42 / 198 | Loss: 7.921130180358887, Learning Rate: 6.720000000000001e-05)
# Step... (44 / 198 | Loss: 2.90024995803833, Learning Rate: 7.04e-05)
# Step... (46 / 198 | Loss: 3.460993528366089, Learning Rate: 7.360000000000001e-05)
# Step... (48 / 198 | Loss: 4.197888374328613, Learning Rate: 7.680000000000001e-05)
# Step... (50 / 198 | Loss: 2.4654054641723633, Learning Rate: 8e-05)
# Step... (52 / 198 | Loss: 3.3281474113464355, Learning Rate: 8e-05)
# Step... (54 / 198 | Loss: 3.767218589782715, Learning Rate: 8e-05)
# Step... (56 / 198 | Loss: 6.584609031677246, Learning Rate: 8e-05)
# Step... (58 / 198 | Loss: 2.7787320613861084, Learning Rate: 8e-05)
# Step... (60 / 198 | Loss: 3.2939910888671875, Learning Rate: 8e-05)
# Step... (62 / 198 | Loss: 3.8310461044311523, Learning Rate: 8e-05)
# Step... (64 / 198 | Loss: 10.916475296020508, Learning Rate: 8e-05)
# Step... (66 / 198 | Loss: 3.393465280532837, Learning Rate: 8e-05)
# Step... (68 / 198 | Loss: 3.4615354537963867, Learning Rate: 8e-05)
# Step... (70 / 198 | Loss: 6.0180535316467285, Learning Rate: 8e-05)
# Step... (72 / 198 | Loss: 2.8800852298736572, Learning Rate: 8e-05)
# Step... (74 / 198 | Loss: 3.080714702606201, Learning Rate: 8e-05)
# Step... (76 / 198 | Loss: 3.4185667037963867, Learning Rate: 8e-05)
# Step... (78 / 198 | Loss: 9.726117134094238, Learning Rate: 8e-05)
# Step... (80 / 198 | Loss: 2.9604616165161133, Learning Rate: 8e-05)
# Step... (82 / 198 | Loss: 3.4231317043304443, Learning Rate: 8e-05)
# Step... (84 / 198 | Loss: 5.073586463928223, Learning Rate: 8e-05)
# Step... (86 / 198 | Loss: 2.2232425212860107, Learning Rate: 8e-05)
# Step... (88 / 198 | Loss: 3.4715664386749268, Learning Rate: 8e-05)
# Step... (90 / 198 | Loss: 3.656508445739746, Learning Rate: 8e-05)
# Step... (92 / 198 | Loss: 7.292297840118408, Learning Rate: 8e-05)
# Step... (94 / 198 | Loss: 3.5792276859283447, Learning Rate: 8e-05)
# Step... (96 / 198 | Loss: 3.3704404830932617, Learning Rate: 8e-05)
# Step... (98 / 198 | Loss: 4.083996772766113, Learning Rate: 8e-05)
# Train steps ... :  50% 99/198 [18:03<17:16, 10.47s/it]
#
# Evaluating - Inference ...:   0% 0/1 [00:00<?, ?it/s]
#
# Evaluating - Inference ...: 100% 1/1 [00:01<00:00,  1.20s/it]
#
#
# Evaluating - Generation ...:   0% 0/1 [00:00<?, ?it/s]
#
# Evaluating - Generation ...: 100% 1/1 [00:47<00:00, 47.32s/it]
#
# config.json: 100% 635/635 [00:00<00:00, 2.56MB/s]
# loading configuration file config.json from cache at /root/.cache/huggingface/hub/models--laion--larger_clap_music_and_speech/snapshots/195c3a3e68faebb3e2088b9a79e79b43ddbda76b/config.json
# text_config is None. Initializing the ClapTextConfig with default values.
# audio_config is None. initializing the ClapAudioConfig with default values.
# Model config ClapConfig {
#   "_name_or_path": "laion/larger_clap_music_and_speech",
#   "architectures": [
#     "ClapModel"
#   ],
#   "audio_config": {
#     "depths": [
#       2,
#       2,
#       12,
#       2
#     ],
#     "hidden_size": 1024,
#     "model_type": "clap_audio_model",
#     "patch_embeds_hidden_size": 128
#   },
#   "hidden_size": 768,
#   "initializer_factor": 1.0,
#   "logit_scale_init_value": 14.285714285714285,
#   "model_type": "clap",
#   "num_hidden_layers": 16,
#   "projection_dim": 512,
#   "projection_hidden_act": "relu",
#   "text_config": {
#     "model_type": "clap_text_model"
#   },
#   "torch_dtype": "float32",
#   "transformers_version": "4.46.1"
# }
#
#
# pytorch_model.bin:   0% 0.00/776M [00:00<?, ?B/s]
# pytorch_model.bin:   1% 10.5M/776M [00:00<00:08, 94.9MB/s]
# pytorch_model.bin:   4% 31.5M/776M [00:00<00:05, 130MB/s]
# pytorch_model.bin:   8% 62.9M/776M [00:00<00:04, 177MB/s]
# pytorch_model.bin:  12% 94.4M/776M [00:00<00:03, 191MB/s]
# pytorch_model.bin:  16% 126M/776M [00:01<00:11, 56.5MB/s]
# pytorch_model.bin:  19% 147M/776M [00:01<00:09, 67.7MB/s]
# pytorch_model.bin:  23% 178M/776M [00:01<00:06, 94.2MB/s]
# pytorch_model.bin:  27% 210M/776M [00:02<00:04, 118MB/s]
# pytorch_model.bin:  31% 241M/776M [00:02<00:03, 140MB/s]
# pytorch_model.bin:  35% 273M/776M [00:02<00:03, 161MB/s]
# pytorch_model.bin:  39% 304M/776M [00:02<00:02, 172MB/s]
# pytorch_model.bin:  43% 336M/776M [00:02<00:02, 184MB/s]
# pytorch_model.bin:  47% 367M/776M [00:02<00:02, 195MB/s]
# pytorch_model.bin:  51% 398M/776M [00:02<00:01, 202MB/s]
# pytorch_model.bin:  55% 430M/776M [00:03<00:01, 208MB/s]
# pytorch_model.bin:  59% 461M/776M [00:03<00:01, 219MB/s]
# pytorch_model.bin:  63% 493M/776M [00:03<00:01, 219MB/s]
# pytorch_model.bin:  68% 524M/776M [00:03<00:01, 220MB/s]
# pytorch_model.bin:  72% 556M/776M [00:03<00:01, 211MB/s]
# pytorch_model.bin:  76% 587M/776M [00:03<00:00, 205MB/s]
# pytorch_model.bin:  78% 608M/776M [00:03<00:00, 205MB/s]
# pytorch_model.bin:  81% 629M/776M [00:04<00:00, 201MB/s]
# pytorch_model.bin:  85% 661M/776M [00:04<00:00, 205MB/s]
# pytorch_model.bin:  88% 682M/776M [00:04<00:00, 115MB/s]
# pytorch_model.bin:  93% 724M/776M [00:04<00:00, 155MB/s]
# pytorch_model.bin:  97% 755M/776M [00:04<00:00, 164MB/s]
# pytorch_model.bin: 100% 776M/776M [00:05<00:00, 154MB/s]
# loading weights file pytorch_model.bin from cache at /root/.cache/huggingface/hub/models--laion--larger_clap_music_and_speech/snapshots/195c3a3e68faebb3e2088b9a79e79b43ddbda76b/pytorch_model.bin
# Attempting to create safetensors variant
# All model checkpoint weights were used when initializing ClapModel.
#
# All the weights of ClapModel were initialized from the model checkpoint at laion/larger_clap_music_and_speech.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use ClapModel for predictions without further training.
#
# preprocessor_config.json: 100% 541/541 [00:00<00:00, 1.73MB/s]
# Attempting to convert .bin model on the fly to safetensors.
# loading configuration file preprocessor_config.json from cache at /root/.cache/huggingface/hub/models--laion--larger_clap_music_and_speech/snapshots/195c3a3e68faebb3e2088b9a79e79b43ddbda76b/preprocessor_config.json
# loading configuration file preprocessor_config.json from cache at /root/.cache/huggingface/hub/models--laion--larger_clap_music_and_speech/snapshots/195c3a3e68faebb3e2088b9a79e79b43ddbda76b/preprocessor_config.json
# Feature extractor ClapFeatureExtractor {
#   "chunk_length_s": 10,
#   "feature_extractor_type": "ClapFeatureExtractor",
#   "feature_size": 64,
#   "fft_window_size": 1024,
#   "frequency_max": 14000,
#   "frequency_min": 50,
#   "hop_length": 480,
#   "max_length_s": 10,
#   "n_fft": 1024,
#   "nb_frequency_bins": 513,
#   "nb_max_frames": 1000,
#   "nb_max_samples": 480000,
#   "padding": "repeatpad",
#   "padding_side": "right",
#   "padding_value": 0.0,
#   "processor_class": "ClapProcessor",
#   "return_attention_mask": false,
#   "sampling_rate": 48000,
#   "top_db": null,
#   "truncation": "rand_trunc"
# }
#
#
# tokenizer_config.json: 100% 1.36k/1.36k [00:00<00:00, 5.67MB/s]
#
# vocab.json:   0% 0.00/798k [00:00<?, ?B/s]
# vocab.json: 100% 798k/798k [00:00<00:00, 1.28MB/s]
#
# merges.txt:   0% 0.00/456k [00:00<?, ?B/s]
# merges.txt: 100% 456k/456k [00:00<00:00, 2.11MB/s]
#
# tokenizer.json:   0% 0.00/2.11M [00:00<?, ?B/s]
# tokenizer.json: 100% 2.11M/2.11M [00:00<00:00, 2.44MB/s]
#
# special_tokens_map.json: 100% 280/280 [00:00<00:00, 1.15MB/s]
# loading file vocab.json from cache at /root/.cache/huggingface/hub/models--laion--larger_clap_music_and_speech/snapshots/195c3a3e68faebb3e2088b9a79e79b43ddbda76b/vocab.json
# loading file merges.txt from cache at /root/.cache/huggingface/hub/models--laion--larger_clap_music_and_speech/snapshots/195c3a3e68faebb3e2088b9a79e79b43ddbda76b/merges.txt
# loading file tokenizer.json from cache at /root/.cache/huggingface/hub/models--laion--larger_clap_music_and_speech/snapshots/195c3a3e68faebb3e2088b9a79e79b43ddbda76b/tokenizer.json
# loading file added_tokens.json from cache at None
# loading file special_tokens_map.json from cache at /root/.cache/huggingface/hub/models--laion--larger_clap_music_and_speech/snapshots/195c3a3e68faebb3e2088b9a79e79b43ddbda76b/special_tokens_map.json
# loading file tokenizer_config.json from cache at /root/.cache/huggingface/hub/models--laion--larger_clap_music_and_speech/snapshots/195c3a3e68faebb3e2088b9a79e79b43ddbda76b/tokenizer_config.json
# Processor ClapProcessor:
# - feature_extractor: ClapFeatureExtractor {
#   "chunk_length_s": 10,
#   "feature_extractor_type": "ClapFeatureExtractor",
#   "feature_size": 64,
#   "fft_window_size": 1024,
#   "frequency_max": 14000,
#   "frequency_min": 50,
#   "hop_length": 480,
#   "max_length_s": 10,
#   "n_fft": 1024,
#   "nb_frequency_bins": 513,
#   "nb_max_frames": 1000,
#   "nb_max_samples": 480000,
#   "padding": "repeatpad",
#   "padding_side": "right",
#   "padding_value": 0.0,
#   "processor_class": "ClapProcessor",
#   "return_attention_mask": false,
#   "sampling_rate": 48000,
#   "top_db": null,
#   "truncation": "rand_trunc"
# }
#
# - tokenizer: RobertaTokenizerFast(name_or_path='laion/larger_clap_music_and_speech', vocab_size=50265, model_max_length=512, is_fast=True, padding_side='right', truncation_side='right', special_tokens={'bos_token': '<s>', 'eos_token': '</s>', 'unk_token': '<unk>', 'sep_token': '</s>', 'pad_token': '<pad>', 'cls_token': '<s>', 'mask_token': '<mask>'}, clean_up_tokenization_spaces=True),  added_tokens_decoder={
# 	0: AddedToken("<s>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	1: AddedToken("<pad>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	2: AddedToken("</s>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# ...
#   "mask_time_prob": 0.05,
#   "max_length": 448,
#   "max_source_positions": 1500,
#   "max_target_positions": 448,
#   "median_filter_width": 7,
#   "model_type": "whisper",
#   "num_hidden_layers": 32,
#   "num_mel_bins": 80,
#   "pad_token_id": 50257,
#   "scale_embedding": false,
#   "suppress_tokens": [
#     1,
#     2,
#     7,
#     8,
#     9,
#     10,
#     14,
#     25,
#     26,
#     27,
#     28,
#     29,
#     31,
#     58,
#     59,
#     60,
#     61,
#     62,
#     63,
#     90,
#     91,
#     92,
#     93,
#     359,
#     503,
#     522,
#     542,
#     873,
#     893,
#     902,
#     918,
#     922,
#     931,
#     1350,
#     1853,
#     1982,
#     2460,
#     2627,
#     3246,
#     3253,
#     3268,
#     3536,
#     3846,
#     3961,
#     4183,
#     4667,
#     6585,
#     6647,
#     7273,
#     9061,
#     9383,
#     10428,
#     10929,
#     11938,
#     12033,
#     12331,
#     12562,
#     13793,
#     14157,
#     14635,
#     15265,
#     15618,
#     16553,
#     16604,
#     18362,
#     18956,
#     20075,
#     21675,
#     22520,
#     26130,
#     26161,
#     26435,
#     28279,
#     29464,
#     31650,
#     32302,
#     32470,
#     36865,
#     42863,
#     47425,
#     49870,
#     50254,
#     50258,
#     50360,
#     50361,
#     50362
#   ],
#   "torch_dtype": "float32",
#   "transformers.js_config": {
#     "use_external_data_format": {
#       "encoder_model.onnx": true
#     }
#   },
#   "transformers_version": "4.46.1",
#   "use_cache": true,
#   "use_weighted_layer_sum": false,
#   "vocab_size": 51865
# }
#
# loading configuration file config.json from cache at /root/.cache/huggingface/hub/models--distil-whisper--distil-large-v2/snapshots/ccb3693e5247bdd734c99eeab96688f8cda3ba72/config.json
# Model config WhisperConfig {
#   "_name_or_path": "distil-whisper/distil-large-v2",
#   "activation_dropout": 0.0,
#   "activation_function": "gelu",
#   "apply_spec_augment": false,
#   "architectures": [
#     "WhisperForConditionalGeneration"
#   ],
#   "attention_dropout": 0.0,
#   "begin_suppress_tokens": [
#     220,
#     50257
#   ],
#   "bos_token_id": 50257,
#   "classifier_proj_size": 256,
#   "d_model": 1280,
#   "decoder_attention_heads": 20,
#   "decoder_ffn_dim": 5120,
#   "decoder_layerdrop": 0.0,
#   "decoder_layers": 2,
#   "decoder_start_token_id": 50258,
#   "dropout": 0.0,
#   "encoder_attention_heads": 20,
#   "encoder_ffn_dim": 5120,
#   "encoder_layerdrop": 0.0,
#   "encoder_layers": 32,
#   "eos_token_id": 50257,
#   "forced_decoder_ids": [
#     [
#       1,
#       50259
#     ],
#     [
#       2,
#       50359
#     ],
#     [
#       3,
#       50363
#     ]
#   ],
#   "init_std": 0.02,
#   "is_encoder_decoder": true,
#   "mask_feature_length": 10,
#   "mask_feature_min_masks": 0,
#   "mask_feature_prob": 0.0,
#   "mask_time_length": 10,
#   "mask_time_min_masks": 2,
#   "mask_time_prob": 0.05,
#   "max_length": 448,
#   "max_source_positions": 1500,
#   "max_target_positions": 448,
#   "median_filter_width": 7,
#   "model_type": "whisper",
#   "num_hidden_layers": 32,
#   "num_mel_bins": 80,
#   "pad_token_id": 50257,
#   "scale_embedding": false,
#   "suppress_tokens": [
#     1,
#     2,
#     7,
#     8,
#     9,
#     10,
#     14,
#     25,
#     26,
#     27,
#     28,
#     29,
#     31,
#     58,
#     59,
#     60,
#     61,
#     62,
#     63,
#     90,
#     91,
#     92,
#     93,
#     359,
#     503,
#     522,
#     542,
#     873,
#     893,
#     902,
#     918,
#     922,
#     931,
#     1350,
#     1853,
#     1982,
#     2460,
#     2627,
#     3246,
#     3253,
#     3268,
#     3536,
#     3846,
#     3961,
#     4183,
#     4667,
#     6585,
#     6647,
#     7273,
#     9061,
#     9383,
#     10428,
#     10929,
#     11938,
#     12033,
#     12331,
#     12562,
#     13793,
#     14157,
#     14635,
#     15265,
#     15618,
#     16553,
#     16604,
#     18362,
#     18956,
#     20075,
#     21675,
#     22520,
#     26130,
#     26161,
#     26435,
#     28279,
#     29464,
#     31650,
#     32302,
#     32470,
#     36865,
#     42863,
#     47425,
#     49870,
#     50254,
#     50258,
#     50360,
#     50361,
#     50362
#   ],
#   "torch_dtype": "float32",
#   "transformers.js_config": {
#     "use_external_data_format": {
#       "encoder_model.onnx": true
#     }
#   },
#   "transformers_version": "4.46.1",
#   "use_cache": true,
#   "use_weighted_layer_sum": false,
#   "vocab_size": 51865
# }
#
# loading weights file model.safetensors from cache at /root/.cache/huggingface/hub/models--distil-whisper--distil-large-v2/snapshots/ccb3693e5247bdd734c99eeab96688f8cda3ba72/model.safetensors
# Generate config GenerationConfig {
#   "begin_suppress_tokens": [
#     220,
#     50257
#   ],
#   "bos_token_id": 50257,
#   "decoder_start_token_id": 50258,
#   "eos_token_id": 50257,
#   "forced_decoder_ids": [
#     [
#       1,
#       50259
#     ],
#     [
#       2,
#       50359
#     ],
#     [
#       3,
#       50363
#     ]
#   ],
#   "max_length": 448,
#   "pad_token_id": 50257,
#   "suppress_tokens": [
#     1,
#     2,
#     7,
#     8,
#     9,
#     10,
#     14,
#     25,
#     26,
#     27,
#     28,
#     29,
#     31,
#     58,
#     59,
#     60,
#     61,
#     62,
#     63,
#     90,
#     91,
#     92,
#     93,
#     359,
#     503,
#     522,
#     542,
#     873,
#     893,
#     902,
#     918,
#     922,
#     931,
#     1350,
#     1853,
#     1982,
#     2460,
#     2627,
#     3246,
#     3253,
#     3268,
#     3536,
#     3846,
#     3961,
#     4183,
#     4667,
#     6585,
#     6647,
#     7273,
#     9061,
#     9383,
#     10428,
#     10929,
#     11938,
#     12033,
#     12331,
#     12562,
#     13793,
#     14157,
#     14635,
#     15265,
#     15618,
#     16553,
#     16604,
#     18362,
#     18956,
#     20075,
#     21675,
#     22520,
#     26130,
#     26161,
#     26435,
#     28279,
#     29464,
#     31650,
#     32302,
#     32470,
#     36865,
#     42863,
#     47425,
#     49870,
#     50254,
#     50258,
#     50360,
#     50361,
#     50362
#   ]
# }
#
# All model checkpoint weights were used when initializing WhisperForConditionalGeneration.
#
# All the weights of WhisperForConditionalGeneration were initialized from the model checkpoint at distil-whisper/distil-large-v2.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use WhisperForConditionalGeneration for predictions without further training.
# loading configuration file generation_config.json from cache at /root/.cache/huggingface/hub/models--distil-whisper--distil-large-v2/snapshots/ccb3693e5247bdd734c99eeab96688f8cda3ba72/generation_config.json
# Generate config GenerationConfig {
#   "begin_suppress_tokens": [
#     220,
#     50257
#   ],
#   "bos_token_id": 50257,
#   "decoder_start_token_id": 50258,
#   "eos_token_id": 50257,
#   "forced_decoder_ids": [
#     [
#       1,
#       50259
#     ],
#     [
#       2,
#       50359
#     ],
#     [
#       3,
#       50363
#     ]
#   ],
#   "is_multilingual": true,
#   "lang_to_id": {
#     "<|af|>": 50327,
#     "<|am|>": 50334,
#     "<|ar|>": 50272,
#     "<|as|>": 50350,
#     "<|az|>": 50304,
#     "<|ba|>": 50355,
#     "<|be|>": 50330,
#     "<|bg|>": 50292,
#     "<|bn|>": 50302,
#     "<|bo|>": 50347,
#     "<|br|>": 50309,
#     "<|bs|>": 50315,
#     "<|ca|>": 50270,
#     "<|cs|>": 50283,
#     "<|cy|>": 50297,
#     "<|da|>": 50285,
#     "<|de|>": 50261,
#     "<|el|>": 50281,
#     "<|en|>": 50259,
#     "<|es|>": 50262,
#     "<|et|>": 50307,
#     "<|eu|>": 50310,
#     "<|fa|>": 50300,
#     "<|fi|>": 50277,
#     "<|fo|>": 50338,
#     "<|fr|>": 50265,
#     "<|gl|>": 50319,
#     "<|gu|>": 50333,
#     "<|haw|>": 50352,
#     "<|ha|>": 50354,
#     "<|he|>": 50279,
#     "<|hi|>": 50276,
#     "<|hr|>": 50291,
#     "<|ht|>": 50339,
#     "<|hu|>": 50286,
#     "<|hy|>": 50312,
#     "<|id|>": 50275,
#     "<|is|>": 50311,
#     "<|it|>": 50274,
#     "<|ja|>": 50266,
#     "<|jw|>": 50356,
#     "<|ka|>": 50329,
#     "<|kk|>": 50316,
#     "<|km|>": 50323,
#     "<|kn|>": 50306,
#     "<|ko|>": 50264,
#     "<|la|>": 50294,
#     "<|lb|>": 50345,
#     "<|ln|>": 50353,
#     "<|lo|>": 50336,
#     "<|lt|>": 50293,
#     "<|lv|>": 50301,
#     "<|mg|>": 50349,
#     "<|mi|>": 50295,
#     "<|mk|>": 50308,
#     "<|ml|>": 50296,
#     "<|mn|>": 50314,
#     "<|mr|>": 50320,
#     "<|ms|>": 50282,
#     "<|mt|>": 50343,
#     "<|my|>": 50346,
#     "<|ne|>": 50313,
#     "<|nl|>": 50271,
#     "<|nn|>": 50342,
#     "<|no|>": 50288,
#     "<|oc|>": 50328,
#     "<|pa|>": 50321,
#     "<|pl|>": 50269,
#     "<|ps|>": 50340,
#     "<|pt|>": 50267,
#     "<|ro|>": 50284,
#     "<|ru|>": 50263,
#     "<|sa|>": 50344,
#     "<|sd|>": 50332,
#     "<|si|>": 50322,
#     "<|sk|>": 50298,
#     "<|sl|>": 50305,
#     "<|sn|>": 50324,
#     "<|so|>": 50326,
#     "<|sq|>": 50317,
#     "<|sr|>": 50303,
#     "<|su|>": 50357,
#     "<|sv|>": 50273,
#     "<|sw|>": 50318,
#     "<|ta|>": 50287,
#     "<|te|>": 50299,
#     "<|tg|>": 50331,
#     "<|th|>": 50289,
#     "<|tk|>": 50341,
#     "<|tl|>": 50348,
#     "<|tr|>": 50268,
#     "<|tt|>": 50351,
#     "<|uk|>": 50280,
#     "<|ur|>": 50290,
#     "<|uz|>": 50337,
#     "<|vi|>": 50278,
#     "<|yi|>": 50335,
#     "<|yo|>": 50325,
#     "<|zh|>": 50260
#   },
#   "language": "<|en|>",
#   "max_initial_timestamp_index": 50,
#   "max_length": 448,
#   "no_timestamps_token_id": 50363,
#   "pad_token_id": 50257,
#   "prev_sot_token_id": 50361,
#   "return_timestamps": false,
#   "suppress_tokens": [
#     1,
#     2,
#     7,
#     8,
#     9,
#     10,
#     14,
#     25,
#     26,
#     27,
#     28,
#     29,
#     31,
#     58,
#     59,
#     60,
#     61,
#     62,
#     63,
#     90,
#     91,
#     92,
#     93,
#     359,
#     503,
#     522,
#     542,
#     873,
#     893,
#     902,
#     918,
#     922,
#     931,
#     1350,
#     1853,
#     1982,
#     2460,
#     2627,
#     3246,
#     3253,
#     3268,
#     3536,
#     3846,
#     3961,
#     4183,
#     4667,
#     6585,
#     6647,
#     7273,
#     9061,
#     9383,
#     10428,
#     10929,
#     11938,
#     12033,
#     12331,
#     12562,
#     13793,
#     14157,
#     14635,
#     15265,
#     15618,
#     16553,
#     16604,
#     18362,
#     18956,
#     20075,
#     21675,
#     22520,
#     26130,
#     26161,
#     26435,
#     28279,
#     29464,
#     31650,
#     32302,
#     32470,
#     36865,
#     42863,
#     47425,
#     49870,
#     50254,
#     50258,
#     50360,
#     50361,
#     50362
#   ],
#   "task": "transcribe",
#   "task_to_id": {
#     "transcribe": 50359,
#     "translate": 50358
#   },
#   "use_scan": false
# }
#
# loading file vocab.json from cache at /root/.cache/huggingface/hub/models--distil-whisper--distil-large-v2/snapshots/ccb3693e5247bdd734c99eeab96688f8cda3ba72/vocab.json
# loading file tokenizer.json from cache at /root/.cache/huggingface/hub/models--distil-whisper--distil-large-v2/snapshots/ccb3693e5247bdd734c99eeab96688f8cda3ba72/tokenizer.json
# loading file merges.txt from cache at /root/.cache/huggingface/hub/models--distil-whisper--distil-large-v2/snapshots/ccb3693e5247bdd734c99eeab96688f8cda3ba72/merges.txt
# loading file normalizer.json from cache at /root/.cache/huggingface/hub/models--distil-whisper--distil-large-v2/snapshots/ccb3693e5247bdd734c99eeab96688f8cda3ba72/normalizer.json
# loading file added_tokens.json from cache at /root/.cache/huggingface/hub/models--distil-whisper--distil-large-v2/snapshots/ccb3693e5247bdd734c99eeab96688f8cda3ba72/added_tokens.json
# loading file special_tokens_map.json from cache at /root/.cache/huggingface/hub/models--distil-whisper--distil-large-v2/snapshots/ccb3693e5247bdd734c99eeab96688f8cda3ba72/special_tokens_map.json
# loading file tokenizer_config.json from cache at /root/.cache/huggingface/hub/models--distil-whisper--distil-large-v2/snapshots/ccb3693e5247bdd734c99eeab96688f8cda3ba72/tokenizer_config.json
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
# loading configuration file preprocessor_config.json from cache at /root/.cache/huggingface/hub/models--distil-whisper--distil-large-v2/snapshots/ccb3693e5247bdd734c99eeab96688f8cda3ba72/preprocessor_config.json
# Feature extractor WhisperFeatureExtractor {
#   "chunk_length": 30,
#   "feature_extractor_type": "WhisperFeatureExtractor",
#   "feature_size": 80,
#   "hop_length": 160,
#   "n_fft": 400,
#   "n_samples": 480000,
#   "nb_max_frames": 3000,
#   "padding_side": "right",
#   "padding_value": 0.0,
#   "processor_class": "WhisperProcessor",
#   "return_attention_mask": false,
#   "sampling_rate": 16000
# }
#
# /usr/local/lib/python3.11/dist-packages/transformers/models/whisper/generation_whisper.py:509: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Increase max_length from 448 to 448 since input is conditioned on previous segment.
# Eval results for step (198 / 198 | Eval Loss: 4.308634281158447 | Eval clap: 0.43354371190071106 | Eval wer: 15.789473684210526 | Eval clean_wer: 15.789473684210526 | Eval noisy_word_error: 0 | Eval percent_clean_samples: 1.0 |)
# wandb:
# wandb:
# wandb: Run history:
# wandb:  codebook_eval/codebook_0_loss █▁
# wandb:  codebook_eval/codebook_1_loss █▁
# wandb:  codebook_eval/codebook_2_loss █▁
# wandb:  codebook_eval/codebook_3_loss █▁
# wandb:  codebook_eval/codebook_4_loss █▁
# wandb:  codebook_eval/codebook_5_loss █▁
# wandb:  codebook_eval/codebook_6_loss █▁
# wandb:  codebook_eval/codebook_7_loss █▁
# wandb:  codebook_eval/codebook_8_loss █▁
# wandb: codebook_train/codebook_0_loss ▄█▃▃▂▂▂▁▆▂▂▅▂▂▂▂▂▁▅▂▂▄▂▂▁▂▂▁▅▂▂▄▂▂▁▂▂▁▅▂
# wandb: codebook_train/codebook_1_loss ▃█▃▃▃▂▃▁▇▂▂▆▃▂▂▂▂▁▆▂▂▅▂▂▂▂▂▁▇▂▂▅▃▂▁▂▂▁▇▃
# wandb: codebook_train/codebook_2_loss ▃█▃▃▂▃▃▁▇▂▂▆▃▂▂▂▂▁▇▂▂▅▃▂▂▂▂▂▇▂▂▆▃▂▂▂▃▁▇▃
# wandb: codebook_train/codebook_3_loss ▃█▃▃▂▃▃▁▇▂▂▆▃▂▂▂▂▁▇▂▂▅▃▂▂▂▂▂▇▂▂▆▃▂▂▂▂▁▇▃
# wandb: codebook_train/codebook_4_loss ▃█▃▃▃▃▃▁▇▂▂▆▃▂▂▂▂▁▇▂▂▅▃▂▂▂▃▂▇▂▂▆▃▂▂▃▃▂█▃
# wandb: codebook_train/codebook_5_loss ▃█▃▃▂▃▃▁▇▂▂▆▃▂▂▂▂▁▆▂▂▅▃▂▂▂▂▂▇▂▂▅▃▂▂▂▂▂▇▃
# wandb: codebook_train/codebook_6_loss ▄█▃▃▂▃▃▁▇▂▂▆▃▂▂▂▂▁▆▂▂▅▃▂▂▂▂▂▇▂▂▆▃▂▂▂▃▁▇▃
# wandb: codebook_train/codebook_7_loss ▃█▃▃▂▃▃▁▇▂▂▆▃▂▂▂▂▁▆▂▂▅▃▂▂▂▂▂▇▂▂▅▃▂▂▂▃▂▇▃
# wandb: codebook_train/codebook_8_loss ▃█▃▃▂▃▃▁▇▂▂▆▃▂▂▂▂▁▆▂▂▅▃▂▂▂▂▂▇▂▂▆▃▂▂▃▃▂▇▃
# wandb:                      eval/clap █▁
# wandb:                 eval/clean_wer ▁█
# wandb:                     eval/epoch ▁█
# wandb:                      eval/loss █▁
# wandb:          eval/noisy_word_error ▁▁
# wandb:     eval/percent_clean_samples ▁▁
# wandb:                      eval/time █▁
# wandb:                       eval/wer ▁█
# wandb:                    train/epoch ▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁████████████████████
# wandb:                train/grad_norm █▇▄▃▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁
# wandb:            train/learning_rate ▁▂▂▃▄▅▅▆▇▇██████████████████████████████
# wandb:                     train/loss ▃█▃▃▂▃▃▁▇▂▂▆▃▂▂▂▂▁▆▂▂▅▃▂▂▂▂▂▇▂▂▅▃▂▂▂▂▁▇▃
# wandb:                     train/time ▁▁▁▂▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███
# wandb:
# wandb: Run summary:
# wandb:  codebook_eval/codebook_0_loss 2.76112
# wandb:  codebook_eval/codebook_1_loss 3.96388
# wandb:  codebook_eval/codebook_2_loss 4.35381
# wandb:  codebook_eval/codebook_3_loss 4.58465
# wandb:  codebook_eval/codebook_4_loss 4.64363
# wandb:  codebook_eval/codebook_5_loss 4.62385
# wandb:  codebook_eval/codebook_6_loss 4.54176
# wandb:  codebook_eval/codebook_7_loss 4.60861
# wandb:  codebook_eval/codebook_8_loss 4.69641
# wandb: codebook_train/codebook_0_loss 2.51864
# wandb: codebook_train/codebook_1_loss 3.47465
# wandb: codebook_train/codebook_2_loss 3.81796
# wandb: codebook_train/codebook_3_loss 3.99907
# wandb: codebook_train/codebook_4_loss 3.97238
# wandb: codebook_train/codebook_5_loss 4.05695
# wandb: codebook_train/codebook_6_loss 3.95115
# wandb: codebook_train/codebook_7_loss 4.04677
# wandb: codebook_train/codebook_8_loss 4.05055
# wandb:                      eval/clap 0.43354
# wandb:                 eval/clean_wer 15.78947
# wandb:                     eval/epoch 1
# wandb:                      eval/loss 4.30863
# wandb:          eval/noisy_word_error 0
# wandb:     eval/percent_clean_samples 1.0
# wandb:                      eval/time 47.6307
# wandb:                       eval/wer 15.78947
# wandb:                    train/epoch 1
# wandb:                train/grad_norm 0.19545
# wandb:            train/learning_rate 8e-05
# wandb:                     train/loss 3.76535
# wandb:                     train/time 2162.16034
# wandb:
# wandb: You can sync this run to the cloud by running:
# wandb: wandb sync /content/parler-tts/wandb/offline-run-20250312_055553-31g0ghty
# wandb: Find logs at: ./wandb/offline-run-20250312_055553-31g0ghty/logs
# /usr/local/lib/python3.11/dist-packages/wandb/sdk/wandb_run.py:2265: UserWarning: Run (31g0ghty) is finished. The call to `_console_raw_callback` will be ignored. Please make sure that you are using an active run.
#   lambda data: self._console_raw_callback("stderr", data),
# Train steps ... : 100% 198/198 [43:01<00:00, 13.04s/it]

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## Inference
#
# The full training on the free T4 from Google Colab took about an hour.
# Now, let's see how to do inference with the newly fine-tuned model!

# %% [markdown]
# First install the Parler-TTS library:

# %%
# !pip install git+https://github.com/huggingface/parler-tts.git
# Out:
# Collecting git+https://github.com/huggingface/parler-tts.git
#   Cloning https://github.com/huggingface/parler-tts.git to /tmp/pip-req-build-e8y2nz9s
#   Running command git clone --filter=blob:none --quiet https://github.com/huggingface/parler-tts.git /tmp/pip-req-build-e8y2nz9s
#   Resolved https://github.com/huggingface/parler-tts.git to commit d108732cd57788ec86bc857d99a6cabd66663d68
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting descript-audiotools@ git+https://github.com/descriptinc/audiotools (from parler_tts==0.2.2)
#   Cloning https://github.com/descriptinc/audiotools to /tmp/pip-install-9g7_7bqt/descript-audiotools_8fa783cafd18443c90d4b2cde8867c36
#   Running command git clone --filter=blob:none --quiet https://github.com/descriptinc/audiotools /tmp/pip-install-9g7_7bqt/descript-audiotools_8fa783cafd18443c90d4b2cde8867c36
#   Resolved https://github.com/descriptinc/audiotools to commit 348ebf2034ce24e2a91a553e3171cb00c0c71678
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: transformers<=4.46.1,>=4.46.1 in /usr/local/lib/python3.11/dist-packages (from parler_tts==0.2.2) (4.46.1)
# Requirement already satisfied: torch in /usr/local/lib/python3.11/dist-packages (from parler_tts==0.2.2) (2.5.1+cu124)
# Requirement already satisfied: sentencepiece in /usr/local/lib/python3.11/dist-packages (from parler_tts==0.2.2) (0.2.0)
# Requirement already satisfied: descript-audio-codec in /usr/local/lib/python3.11/dist-packages (from parler_tts==0.2.2) (1.0.0)
# Requirement already satisfied: protobuf>=4.0.0 in /usr/local/lib/python3.11/dist-packages (from parler_tts==0.2.2) (4.25.6)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from transformers<=4.46.1,>=4.46.1->parler_tts==0.2.2) (3.17.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.23.2 in /usr/local/lib/python3.11/dist-packages (from transformers<=4.46.1,>=4.46.1->parler_tts==0.2.2) (0.28.1)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.11/dist-packages (from transformers<=4.46.1,>=4.46.1->parler_tts==0.2.2) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from transformers<=4.46.1,>=4.46.1->parler_tts==0.2.2) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.11/dist-packages (from transformers<=4.46.1,>=4.46.1->parler_tts==0.2.2) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.11/dist-packages (from transformers<=4.46.1,>=4.46.1->parler_tts==0.2.2) (2024.11.6)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from transformers<=4.46.1,>=4.46.1->parler_tts==0.2.2) (2.32.3)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.11/dist-packages (from transformers<=4.46.1,>=4.46.1->parler_tts==0.2.2) (0.5.3)
# Requirement already satisfied: tokenizers<0.21,>=0.20 in /usr/local/lib/python3.11/dist-packages (from transformers<=4.46.1,>=4.46.1->parler_tts==0.2.2) (0.20.3)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.11/dist-packages (from transformers<=4.46.1,>=4.46.1->parler_tts==0.2.2) (4.67.1)
# Requirement already satisfied: argbind>=0.3.7 in /usr/local/lib/python3.11/dist-packages (from descript-audio-codec->parler_tts==0.2.2) (0.3.9)
# Requirement already satisfied: einops in /usr/local/lib/python3.11/dist-packages (from descript-audio-codec->parler_tts==0.2.2) (0.8.1)
# Requirement already satisfied: torchaudio in /usr/local/lib/python3.11/dist-packages (from descript-audio-codec->parler_tts==0.2.2) (2.5.1+cu124)
# Requirement already satisfied: soundfile in /usr/local/lib/python3.11/dist-packages (from descript-audiotools@ git+https://github.com/descriptinc/audiotools->parler_tts==0.2.2) (0.13.1)
# Requirement already satisfied: pyloudnorm in /usr/local/lib/python3.11/dist-packages (from descript-audiotools@ git+https://github.com/descriptinc/audiotools->parler_tts==0.2.2) (0.1.1)
# Requirement already satisfied: importlib-resources in /usr/local/lib/python3.11/dist-packages (from descript-audiotools@ git+https://github.com/descriptinc/audiotools->parler_tts==0.2.2) (6.5.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.11/dist-packages (from descript-audiotools@ git+https://github.com/descriptinc/audiotools->parler_tts==0.2.2) (1.14.1)
# Requirement already satisfied: julius in /usr/local/lib/python3.11/dist-packages (from descript-audiotools@ git+https://github.com/descriptinc/audiotools->parler_tts==0.2.2) (0.2.7)
# Requirement already satisfied: ffmpy in /usr/local/lib/python3.11/dist-packages (from descript-audiotools@ git+https://github.com/descriptinc/audiotools->parler_tts==0.2.2) (0.5.0)
# Requirement already satisfied: ipython in /usr/local/lib/python3.11/dist-packages (from descript-audiotools@ git+https://github.com/descriptinc/audiotools->parler_tts==0.2.2) (7.34.0)
# Requirement already satisfied: rich in /usr/local/lib/python3.11/dist-packages (from descript-audiotools@ git+https://github.com/descriptinc/audiotools->parler_tts==0.2.2) (13.9.4)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.11/dist-packages (from descript-audiotools@ git+https://github.com/descriptinc/audiotools->parler_tts==0.2.2) (3.10.0)
# Requirement already satisfied: librosa in /usr/local/lib/python3.11/dist-packages (from descript-audiotools@ git+https://github.com/descriptinc/audiotools->parler_tts==0.2.2) (0.10.2.post1)
# Requirement already satisfied: pystoi in /usr/local/lib/python3.11/dist-packages (from descript-audiotools@ git+https://github.com/descriptinc/audiotools->parler_tts==0.2.2) (0.4.1)
# Requirement already satisfied: torch_stoi in /usr/local/lib/python3.11/dist-packages (from descript-audiotools@ git+https://github.com/descriptinc/audiotools->parler_tts==0.2.2) (0.2.3)
# Requirement already satisfied: flatten-dict in /usr/local/lib/python3.11/dist-packages (from descript-audiotools@ git+https://github.com/descriptinc/audiotools->parler_tts==0.2.2) (0.4.2)
# Requirement already satisfied: markdown2 in /usr/local/lib/python3.11/dist-packages (from descript-audiotools@ git+https://github.com/descriptinc/audiotools->parler_tts==0.2.2) (2.5.3)
# Requirement already satisfied: randomname in /usr/local/lib/python3.11/dist-packages (from descript-audiotools@ git+https://github.com/descriptinc/audiotools->parler_tts==0.2.2) (0.2.1)
# Requirement already satisfied: tensorboard in /usr/local/lib/python3.11/dist-packages (from descript-audiotools@ git+https://github.com/descriptinc/audiotools->parler_tts==0.2.2) (2.18.0)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.11/dist-packages (from torch->parler_tts==0.2.2) (4.12.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch->parler_tts==0.2.2) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch->parler_tts==0.2.2) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch->parler_tts==0.2.2) (2024.10.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch->parler_tts==0.2.2) (12.4.127)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch->parler_tts==0.2.2) (12.4.127)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch->parler_tts==0.2.2) (12.4.127)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /usr/local/lib/python3.11/dist-packages (from torch->parler_tts==0.2.2) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.4.5.8 in /usr/local/lib/python3.11/dist-packages (from torch->parler_tts==0.2.2) (12.4.5.8)
# Requirement already satisfied: nvidia-cufft-cu12==11.2.1.3 in /usr/local/lib/python3.11/dist-packages (from torch->parler_tts==0.2.2) (11.2.1.3)
# Requirement already satisfied: nvidia-curand-cu12==10.3.5.147 in /usr/local/lib/python3.11/dist-packages (from torch->parler_tts==0.2.2) (10.3.5.147)
# Requirement already satisfied: nvidia-cusolver-cu12==11.6.1.9 in /usr/local/lib/python3.11/dist-packages (from torch->parler_tts==0.2.2) (11.6.1.9)
# Requirement already satisfied: nvidia-cusparse-cu12==12.3.1.170 in /usr/local/lib/python3.11/dist-packages (from torch->parler_tts==0.2.2) (12.3.1.170)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch->parler_tts==0.2.2) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch->parler_tts==0.2.2) (12.4.127)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch->parler_tts==0.2.2) (12.4.127)
# Requirement already satisfied: triton==3.1.0 in /usr/local/lib/python3.11/dist-packages (from torch->parler_tts==0.2.2) (3.1.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch->parler_tts==0.2.2) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch->parler_tts==0.2.2) (1.3.0)
# Requirement already satisfied: docstring-parser in /usr/local/lib/python3.11/dist-packages (from argbind>=0.3.7->descript-audio-codec->parler_tts==0.2.2) (0.16)
# Requirement already satisfied: six<2.0,>=1.12 in /usr/local/lib/python3.11/dist-packages (from flatten-dict->descript-audiotools@ git+https://github.com/descriptinc/audiotools->parler_tts==0.2.2) (1.17.0)
# Requirement already satisfied: setuptools>=18.5 in /usr/local/lib/python3.11/dist-packages (from ipython->descript-audiotools@ git+https://github.com/descriptinc/audiotools->parler_tts==0.2.2) (75.1.0)
# Requirement already satisfied: jedi>=0.16 in /usr/local/lib/python3.11/dist-packages (from ipython->descript-audiotools@ git+https://github.com/descriptinc/audiotools->parler_tts==0.2.2) (0.19.2)
# Requirement already satisfied: decorator in /usr/local/lib/python3.11/dist-packages (from ipython->descript-audiotools@ git+https://github.com/descriptinc/audiotools->parler_tts==0.2.2) (4.4.2)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.11/dist-packages (from ipython->descript-audiotools@ git+https://github.com/descriptinc/audiotools->parler_tts==0.2.2) (0.7.5)
# Requirement already satisfied: traitlets>=4.2 in /usr/local/lib/python3.11/dist-packages (from ipython->descript-audiotools@ git+https://github.com/descriptinc/audiotools->parler_tts==0.2.2) (5.7.1)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from ipython->descript-audiotools@ git+https://github.com/descriptinc/audiotools->parler_tts==0.2.2) (3.0.50)
# Requirement already satisfied: pygments in /usr/local/lib/python3.11/dist-packages (from ipython->descript-audiotools@ git+https://github.com/descriptinc/audiotools->parler_tts==0.2.2) (2.18.0)
# Requirement already satisfied: backcall in /usr/local/lib/python3.11/dist-packages (from ipython->descript-audiotools@ git+https://github.com/descriptinc/audiotools->parler_tts==0.2.2) (0.2.0)
# Requirement already satisfied: matplotlib-inline in /usr/local/lib/python3.11/dist-packages (from ipython->descript-audiotools@ git+https://github.com/descriptinc/audiotools->parler_tts==0.2.2) (0.1.7)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.11/dist-packages (from ipython->descript-audiotools@ git+https://github.com/descriptinc/audiotools->parler_tts==0.2.2) (4.9.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch->parler_tts==0.2.2) (3.0.2)
# Requirement already satisfied: audioread>=2.1.9 in /usr/local/lib/python3.11/dist-packages (from librosa->descript-audiotools@ git+https://github.com/descriptinc/audiotools->parler_tts==0.2.2) (3.0.1)
# Requirement already satisfied: scikit-learn>=0.20.0 in /usr/local/lib/python3.11/dist-packages (from librosa->descript-audiotools@ git+https://github.com/descriptinc/audiotools->parler_tts==0.2.2) (1.6.1)
# Requirement already satisfied: joblib>=0.14 in /usr/local/lib/python3.11/dist-packages (from librosa->descript-audiotools@ git+https://github.com/descriptinc/audiotools->parler_tts==0.2.2) (1.4.2)
# Requirement already satisfied: numba>=0.51.0 in /usr/local/lib/python3.11/dist-packages (from librosa->descript-audiotools@ git+https://github.com/descriptinc/audiotools->parler_tts==0.2.2) (0.60.0)
# Requirement already satisfied: pooch>=1.1 in /usr/local/lib/python3.11/dist-packages (from librosa->descript-audiotools@ git+https://github.com/descriptinc/audiotools->parler_tts==0.2.2) (1.8.2)
# Requirement already satisfied: soxr>=0.3.2 in /usr/local/lib/python3.11/dist-packages (from librosa->descript-audiotools@ git+https://github.com/descriptinc/audiotools->parler_tts==0.2.2) (0.5.0.post1)
# Requirement already satisfied: lazy-loader>=0.1 in /usr/local/lib/python3.11/dist-packages (from librosa->descript-audiotools@ git+https://github.com/descriptinc/audiotools->parler_tts==0.2.2) (0.4)
# Requirement already satisfied: msgpack>=1.0 in /usr/local/lib/python3.11/dist-packages (from librosa->descript-audiotools@ git+https://github.com/descriptinc/audiotools->parler_tts==0.2.2) (1.1.0)
# Requirement already satisfied: cffi>=1.0 in /usr/local/lib/python3.11/dist-packages (from soundfile->descript-audiotools@ git+https://github.com/descriptinc/audiotools->parler_tts==0.2.2) (1.17.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->descript-audiotools@ git+https://github.com/descriptinc/audiotools->parler_tts==0.2.2) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib->descript-audiotools@ git+https://github.com/descriptinc/audiotools->parler_tts==0.2.2) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->descript-audiotools@ git+https://github.com/descriptinc/audiotools->parler_tts==0.2.2) (4.56.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->descript-audiotools@ git+https://github.com/descriptinc/audiotools->parler_tts==0.2.2) (1.4.8)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.11/dist-packages (from matplotlib->descript-audiotools@ git+https://github.com/descriptinc/audiotools->parler_tts==0.2.2) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->descript-audiotools@ git+https://github.com/descriptinc/audiotools->parler_tts==0.2.2) (3.2.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib->descript-audiotools@ git+https://github.com/descriptinc/audiotools->parler_tts==0.2.2) (2.8.2)
# Requirement already satisfied: future>=0.16.0 in /usr/local/lib/python3.11/dist-packages (from pyloudnorm->descript-audiotools@ git+https://github.com/descriptinc/audiotools->parler_tts==0.2.2) (1.0.0)
# Requirement already satisfied: fire in /usr/local/lib/python3.11/dist-packages (from randomname->descript-audiotools@ git+https://github.com/descriptinc/audiotools->parler_tts==0.2.2) (0.7.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->transformers<=4.46.1,>=4.46.1->parler_tts==0.2.2) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->transformers<=4.46.1,>=4.46.1->parler_tts==0.2.2) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->transformers<=4.46.1,>=4.46.1->parler_tts==0.2.2) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->transformers<=4.46.1,>=4.46.1->parler_tts==0.2.2) (2025.1.31)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.11/dist-packages (from rich->descript-audiotools@ git+https://github.com/descriptinc/audiotools->parler_tts==0.2.2) (3.0.0)
# Requirement already satisfied: absl-py>=0.4 in /usr/local/lib/python3.11/dist-packages (from tensorboard->descript-audiotools@ git+https://github.com/descriptinc/audiotools->parler_tts==0.2.2) (1.4.0)
# Requirement already satisfied: grpcio>=1.48.2 in /usr/local/lib/python3.11/dist-packages (from tensorboard->descript-audiotools@ git+https://github.com/descriptinc/audiotools->parler_tts==0.2.2) (1.70.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.11/dist-packages (from tensorboard->descript-audiotools@ git+https://github.com/descriptinc/audiotools->parler_tts==0.2.2) (3.7)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.11/dist-packages (from tensorboard->descript-audiotools@ git+https://github.com/descriptinc/audiotools->parler_tts==0.2.2) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from tensorboard->descript-audiotools@ git+https://github.com/descriptinc/audiotools->parler_tts==0.2.2) (3.1.3)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.11/dist-packages (from cffi>=1.0->soundfile->descript-audiotools@ git+https://github.com/descriptinc/audiotools->parler_tts==0.2.2) (2.22)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /usr/local/lib/python3.11/dist-packages (from jedi>=0.16->ipython->descript-audiotools@ git+https://github.com/descriptinc/audiotools->parler_tts==0.2.2) (0.8.4)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.11/dist-packages (from markdown-it-py>=2.2.0->rich->descript-audiotools@ git+https://github.com/descriptinc/audiotools->parler_tts==0.2.2) (0.1.2)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /usr/local/lib/python3.11/dist-packages (from numba>=0.51.0->librosa->descript-audiotools@ git+https://github.com/descriptinc/audiotools->parler_tts==0.2.2) (0.43.0)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.11/dist-packages (from pexpect>4.3->ipython->descript-audiotools@ git+https://github.com/descriptinc/audiotools->parler_tts==0.2.2) (0.7.0)
# Requirement already satisfied: platformdirs>=2.5.0 in /usr/local/lib/python3.11/dist-packages (from pooch>=1.1->librosa->descript-audiotools@ git+https://github.com/descriptinc/audiotools->parler_tts==0.2.2) (4.3.6)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.11/dist-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython->descript-audiotools@ git+https://github.com/descriptinc/audiotools->parler_tts==0.2.2) (0.2.13)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn>=0.20.0->librosa->descript-audiotools@ git+https://github.com/descriptinc/audiotools->parler_tts==0.2.2) (3.5.0)
# Requirement already satisfied: termcolor in /usr/local/lib/python3.11/dist-packages (from fire->randomname->descript-audiotools@ git+https://github.com/descriptinc/audiotools->parler_tts==0.2.2) (2.5.0)
# Building wheels for collected packages: parler_tts
#   Building wheel for parler_tts (pyproject.toml) ... done
#   Created wheel for parler_tts: filename=parler_tts-0.2.2-py3-none-any.whl size=81581 sha256=187ee95a48c57ce32881583c6cd2bd49af9b3f293988c1cac10926a6f982943c
#   Stored in directory: /tmp/pip-ephem-wheel-cache-gddk9a0o/wheels/08/a6/4a/82909c56646ab22ea6ddda9bc9ac105225c571897f1cf08cba
# Successfully built parler_tts
# Installing collected packages: parler_tts
#   Attempting uninstall: parler_tts
#     Found existing installation: parler_tts 0.2.2
#     Uninstalling parler_tts-0.2.2:
#       Successfully uninstalled parler_tts-0.2.2
# Successfully installed parler_tts-0.2.2

# %% [markdown]
# Then:

# %%
from parler_tts import ParlerTTSForConditionalGeneration
from transformers import AutoTokenizer
import torch

device = "cuda:0" if torch.cuda.is_available() else "cpu"

model = ParlerTTSForConditionalGeneration.from_pretrained("/content/parler-tts/output_dir_training", torch_dtype=torch.float16).to(device)
tokenizer = AutoTokenizer.from_pretrained("parler-tts/parler_tts_mini_v0.1")

prompt = "Hey, how are you doing today?"
description = "'Jenny delivers her words quite expressively, in a very confined sounding environment with clear audio quality. She speaks fast.'"

input_ids = tokenizer(description, return_tensors="pt").input_ids.to(device)
prompt_input_ids = tokenizer(prompt, return_tensors="pt").input_ids.to(device)

generation = model.generate(input_ids=input_ids, prompt_input_ids=prompt_input_ids)
audio_arr = generation.cpu().numpy().squeeze()
# Out:
# WARNING:parler_tts.modeling_parler_tts:Flash attention 2 is not installed
# /usr/local/lib/python3.11/dist-packages/torch/nn/utils/weight_norm.py:143: FutureWarning: `torch.nn.utils.weight_norm` is deprecated in favor of `torch.nn.utils.parametrizations.weight_norm`.
#   WeightNorm.apply(module, name, dim)
# WARNING:parler_tts.modeling_parler_tts:Config of the text_encoder: <class 'transformers.models.t5.modeling_t5.T5EncoderModel'> is overwritten by shared text_encoder config: T5Config {
#   "_name_or_path": "google/flan-t5-base",
#   "architectures": [
#     "T5ForConditionalGeneration"
#   ],
#   "classifier_dropout": 0.0,
#   "d_ff": 2048,
#   "d_kv": 64,
#   "d_model": 768,
#   "decoder_start_token_id": 0,
#   "dense_act_fn": "gelu_new",
#   "dropout_rate": 0.1,
#   "eos_token_id": 1,
#   "feed_forward_proj": "gated-gelu",
#   "initializer_factor": 1.0,
#   "is_encoder_decoder": true,
#   "is_gated_act": true,
#   "layer_norm_epsilon": 1e-06,
#   "model_type": "t5",
#   "n_positions": 512,
#   "num_decoder_layers": 12,
#   "num_heads": 12,
#   "num_layers": 12,
#   "output_past": true,
#   "pad_token_id": 0,
#   "relative_attention_max_distance": 128,
#   "relative_attention_num_buckets": 32,
#   "task_specific_params": {
#     "summarization": {
#       "early_stopping": true,
#       "length_penalty": 2.0,
#       "max_length": 200,
#       "min_length": 30,
#       "no_repeat_ngram_size": 3,
#       "num_beams": 4,
#       "prefix": "summarize: "
#     },
#     "translation_en_to_de": {
#       "early_stopping": true,
#       "max_length": 300,
#       "num_beams": 4,
#       "prefix": "translate English to German: "
#     },
#     "translation_en_to_fr": {
#       "early_stopping": true,
#       "max_length": 300,
#       "num_beams": 4,
#       "prefix": "translate English to French: "
#     },
#     "translation_en_to_ro": {
#       "early_stopping": true,
#       "max_length": 300,
#       "num_beams": 4,
#       "prefix": "translate English to Romanian: "
#     }
#   },
#   "tie_word_embeddings": false,
#   "transformers_version": "4.46.1",
#   "use_cache": true,
#   "vocab_size": 32128
# }
#
# WARNING:parler_tts.modeling_parler_tts:Config of the audio_encoder: <class 'parler_tts.dac_wrapper.modeling_dac.DACModel'> is overwritten by shared audio_encoder config: DACConfig {
#   "_name_or_path": "ylacombe/dac_44khZ_8kbps",
#   "architectures": [
#     "DACModel"
#   ],
#   "codebook_size": 1024,
#   "frame_rate": 86,
#   "latent_dim": 1024,
#   "model_bitrate": 8,
#   "model_type": "dac_on_the_hub",
#   "num_codebooks": 9,
#   "sampling_rate": 44100,
#   "torch_dtype": "float32",
#   "transformers_version": "4.46.1"
# }
#
# WARNING:parler_tts.modeling_parler_tts:Config of the decoder: <class 'parler_tts.modeling_parler_tts.ParlerTTSForCausalLM'> is overwritten by shared decoder config: ParlerTTSDecoderConfig {
#   "_name_or_path": "/fsx/yoach/tmp/artefacts/decoder_400M/",
#   "activation_dropout": 0.0,
#   "activation_function": "gelu",
#   "add_cross_attention": true,
#   "architectures": [
#     "ParlerTTSForCausalLM"
#   ],
#   "attention_dropout": 0.0,
#   "bos_token_id": 1025,
#   "codebook_weights": null,
#   "cross_attention_implementation_strategy": null,
#   "dropout": 0.1,
#   "eos_token_id": 1024,
#   "ffn_dim": 4096,
#   "hidden_size": 1024,
#   "initializer_factor": 0.02,
#   "is_decoder": true,
#   "layerdrop": 0.0,
#   "max_position_embeddings": 4096,
#   "model_type": "parler_tts_decoder",
#   "num_attention_heads": 16,
#   "num_codebooks": 9,
#   "num_cross_attention_key_value_heads": 16,
#   "num_hidden_layers": 24,
#   "num_key_value_heads": 16,
#   "pad_token_id": 1024,
#   "rope_embeddings": false,
#   "rope_theta": 10000.0,
#   "scale_embedding": false,
#   "tie_word_embeddings": false,
#   "torch_dtype": "float32",
#   "transformers_version": "4.46.1",
#   "use_cache": true,
#   "use_fused_lm_heads": false,
#   "vocab_size": 1088
# }
#
# You set `add_prefix_space`. The tokenizer needs to be converted from the slow tokenizers
# The attention mask is not set and cannot be inferred from input because pad token is same as eos token. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.

# %%
from IPython.display import Audio
Audio(audio_arr, rate=model.config.sampling_rate)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
prompt = "Wow, I've really got the same voice as Jenny, huh?"

prompt_input_ids = tokenizer(prompt, return_tensors="pt").input_ids.to(device)

generation = model.generate(input_ids=input_ids, prompt_input_ids=prompt_input_ids)
audio_arr = generation.cpu().numpy().squeeze()

Audio(audio_arr, rate=model.config.sampling_rate)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
prompt = "What a time to be alive!"
description = "'Jenny's speech is very clear, and she speaks in a very monotone voice, really slowly and with minimal variation in speed.'"

input_ids = tokenizer(description, return_tensors="pt").input_ids.to(device)
prompt_input_ids = tokenizer(prompt, return_tensors="pt").input_ids.to(device)

generation = model.generate(input_ids=input_ids, prompt_input_ids=prompt_input_ids)
audio_arr = generation.cpu().numpy().squeeze()

Audio(audio_arr, rate=model.config.sampling_rate)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# This is great! As you can see, the model now managed to get a **consistent** voice throughout generation that looks like **Jenny**!
#
# Since we're quite happy about it, let's push it to the hub to be able to re-use it!

# %%
model.push_to_hub("parler-tts-jenny-trial")
tokenizer.push_to_hub("parler-tts-jenny-trial")
# Out:
# model.safetensors:   0%|          | 0.00/1.29G [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/5.17k [00:00<?, ?B/s]
# spiece.model:   0%|          | 0.00/792k [00:00<?, ?B/s]
# CommitInfo(commit_url='https://huggingface.co/hijklmno/parler-tts-jenny-trial/commit/9ac980e4094c7d727a074c49f2467c92afb347a2', commit_message='Upload tokenizer', commit_description='', oid='9ac980e4094c7d727a074c49f2467c92afb347a2', pr_url=None, repo_url=RepoUrl('https://huggingface.co/hijklmno/parler-tts-jenny-trial', endpoint='https://huggingface.co', repo_type='model', repo_id='hijklmno/parler-tts-jenny-trial'), pr_revision=None, pr_num=None)

# %% [markdown]
# You'll now be able to load the model and the tokenizer using the direct repository id of your model, i.e `<your_HF_handle>/parler-tts-mini-Jenny-colab`.
#
# ```python
# model = ParlerTTSForConditionalGeneration.from_pretrained("<your_HF_handle>/parler-tts-mini-Jenny-colab").to(device)
# tokenizer = AutoTokenizer.from_pretrained("<your_HF_handle>/parler-tts-mini-Jenny-colab")
# ```

# %% [markdown]
# ## Conclusion
#
# To conclude, we've shown here:
# 1. how to annotate a single-speaker 6-hours-long dataset
# 2. how to fine-tune Parler-TTS Mini v0.1 on this newly created dataset!
#
# **If you want to fine-tune the model on your own dataset, you can follow and/or adapt the current notebook to make it work! Don't forget to check how to push your own local dataset on the HuggingFace Hub using a [script similar to what's described in the Data-Speech FAQ](https://github.com/huggingface/dataspeech?tab=readme-ov-file#how-do-i-use-datasets-that-i-have-with-this-repository)!**
